# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# **Role:** An Advisor from the education board from US with the task to review scores from 2017 to 2018.
#
# **Objective:** Analyse relationships between scores and participation rates by ACT and SAT students and its association with income levels, and identify areas of improvement for different states across US.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-&-Cleaning)
#     -[2017 Data Import and Cleaning](#2017-Data-Import-and-Cleaning)
#     -[2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
#     -[Merge with Income](#Merge-with-Income)
# - [Data Dictionary](#Data-Dictionary)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# From Washington’s Post, scores from the ACT show that only 9% of students in the class of 2017 who came from low-income families are strongly ready for college in 2017.([*source*](https://www.washingtonpost.com/local/education/we-didnt-know-it-was-this-bad-new-act-scores-show-huge-achievement-gaps/2017/09/06/c6397f36-9279-11e7-aace-04b862b2b3f3_story.html))
#
# This is a cause of concern, as this disparities in college readiness will put students of lower income to a disadvantage competing with the rest, hence less like to have access to high-quality educational and career planning opportunities and resources
#
# Thus, we will need to evaluate both test across 2017 and 2018 and produce improvement plans.

# %% [markdown]
# ### Choose your Data
#
# * [`us_income.csv`](./Data/us_income.csv): US income per capita by states
# * [`act_2017.csv`](./Data/act_2017.csv): ACT scores and participation rate 2017
# * [`act_2018.csv`](./Data/act_2018.csv): ACT scores and participation rate 2018
# * [`sat_2018.csv`](./Data/sat_2018.csv): sat scores and participation rate 2018
# * [`sat_2017.csv`](./Data/sat_2017.csv): sat scores and participation rate 2017
# * [`us_states.csv`](./Data/us_states.csv): US states list

# %% [markdown]
# ### Outside Research

# %% [markdown]
# 1) The higher participation rates the lower the average scores in a state. Research from ACT mentions a 1.22 score poinrts after the adoption for each additional 25% tested. ([*source*](https://www.act.org/content/dam/act/unsecured/documents/Statewide-Adoption.pdf))

# %% [markdown]
# 2) income per capita by US states - 2015. ([*source*](https://www.infoplease.com/business/poverty-income/capita-personal-income-state))

# %% [markdown]
# 4) ACT scores showing disparity between the rich and the poorer states
#
# Efforts should be focused on imporiving the readiness levels for students from lower income families
#  ([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf))

# %% [markdown]
# 5) In the 2017-18 school year, nearly one million students participated in SAT School Day, compared to about 800,000 in 2016-17 and 460,000 in 2015-16. In 2014-15, only three states—Delaware, Idaho, Maine—and the District of Columbia participated in SAT School Day. In 2017-18, 10 states—Colorado, Connecticut, Delaware, Idaho, Illinois, Maine, Michigan, New Hampshire, Rhode Island, West Virginia—and the District of Columbia gave the SAT to public school students for free.
# ([*source*](https://newsroom.collegeboard.org/more-2-million-students-class-2018-took-sat-highest-ever#:~:text=10%2F25%2F2018-,More%20Than%202%20Million%20Students%20in%20the%20Class%20of%202018,gaining%20greater%20access%20and%20opportunity.))

# %% [markdown]
# 6) States require students to take the SAT or ACT ([*source*](https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act))

# %% [markdown]
# 7) Participation-skews-state-averages ([*source*](https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01))

# %% [markdown]
# 8) Colorado and Illinois  has increased participation for SAT, mandate changed on 2017
#
# (Colorado - [*source*](https://testive.com/colorado-sat-change-2017/))
# (Illinois - [*source*](https://testive.com/illinois/))

# %% [markdown]
# 9) ACT correlation with income ([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pd))

# %% [markdown]
# 10) US States list ([*source*](https://www.britannica.com/topic/list-of-state-capitals-in-the-United-States-2119210))

# %% [markdown]
# 11) Because cultural and socioeconomic factors and the quality of schools vary greatly between districts and states, average SAT scores vary greatly ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def getmean(sample):
    number = 0 
    for num in sample:
        number = num + number
        
    return (number/len(sample))

getmean([1,2,4,5,7,2,3,43])
# Out:
# 8.375

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def getstdev(sample):
    number = 0
    for num in sample:
        number = number + ((num-getmean(sample))**2)
    return ((number)/len(sample))**0.5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def remove_percent_conv_float(string):
    return float(''.join([x for x in string if (x =='.') or (x.isdigit())]))/100

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline

# %% [markdown]
# # Initiating data

# %%
# Load sat_2017 & act_2017 datasets
act_2017 = pd.read_csv('Data/act_2017.csv')
sat_2017 = pd.read_csv('Data/sat_2017.csv')
us_income= pd.read_csv('Data/us_income.csv')
us_states= pd.read_csv('Data/us_states.csv')
act_2018 = pd.read_csv('Data/act_2018.csv')
sat_2018 = pd.read_csv('Data/sat_2018.csv')

# %% [markdown]
# ## Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %%
# check headers and contents

act_2017.head(2)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2

# %%
# check headers and contents

sat_2017.head(2)
# Out:
#      State Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5%                                 593   572   1165
# 1   Alaska           38%                                 547   533   1080

# %%
# participation found to be object

act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
# participation found to be object

sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# convert percentage to float
filelist = [sat_2017,act_2017]

for file in filelist:
    file['Participation'] = file['Participation'].apply(lambda x: remove_percent_conv_float(x))

# %%
# define function that tells which string can be converted to float for masking 

def filter_string_Float(string):
        try:
            if float(string):
                return True
        except ValueError:
            return False

# %%
# use lambda to apply function: not (filter_string_Float) 

act_2017[act_2017['Composite'].apply(lambda x: not filter_string_Float(x))]
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 51  Wyoming            1.0     19.4  19.8     20.8     20.6     20.2x

# %%
# define function to convert str to float 
def remove_str_conv_float(string):
    return float(''.join([x for x in string if (x =='.') or (x.isdigit())]))

# %%
# use lambda to apply function: (remove_letters_return_float)

act_2017['Composite'] = act_2017['Composite'].apply(lambda x: remove_str_conv_float(x))

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# **Check if SAT_2017 and ACT_2017 has any wrong US states**

# %%
# define function that checks if its in us_states list

def check_if_USstate(state, ref_state, ref_col):
    return state in ref_state[ref_col].values

# %%
# define function that helps callout duplicated and missing points and reference it to index

def check_dups_missing(df, col, ref_state, ref_col):
    # set variable to contain list of states not in us_states_list
    get_not_in_us = df[df[col].apply(lambda x: not check_if_USstate(x, ref_state, ref_col))]
    #check number of duplicated column names 
    get_duplicates = df[df.duplicated()]
    
    missingdata = len(get_not_in_us)
    dup = len(get_duplicates)
    
    print(f'Df has {missingdata} of missing data')
    print(f'Df has {dup} of duplicated data\n')
    
    if missingdata != 0:
        print(f'\
Array of missing data under column: "{col}"\n\
Missing data array: {get_not_in_us[col].values} \
at Index: {get_not_in_us[col].index.values}\n\
        ')
    else:
        print('No missing dataframe\n')
    
    if dup != 0:
        print(f'\
Array of duplicated data under column: "{col}" \n\
Duplicated words: {get_duplicates[col].values} \
at Index: {get_duplicates.index.values}\
        ')
    else:
        print('No duplicated dataframe')

# %%
# run function to detect duplicates or missing data

check_dups_missing(act_2017,'State',us_states,'state')
# Out:
# Df has 2 of missing data
# Df has 0 of duplicated data
#
# Array of missing data under column: "State"
# Missing data array: ['National' 'District of Columbia'] at Index: [0 9]
#
# No duplicated dataframe

# %%
act_2017[act_2017['State'] == 'National']
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0

# %%
# Dropping national row
act_2017.drop(index = 0, inplace = True)
act_2017.reset_index(drop=True, inplace=True)

# %%
act_2017[act_2017['State'] == 'District of Columbia']
# Out:
#                   State  Participation  English  Math  Reading  Science  \
# 8  District of Columbia           0.32     24.4  23.5     24.9     23.5
#
#    Composite
# 8       24.2

# %%
sat_2017[sat_2017['State'] == 'District of Columbia']
# Out:
#                   State  Participation  Evidence-Based Reading and Writing  \
# 8  District of Columbia            1.0                                 482
#
#    Math  Total
# 8   468    950

# %%
# Answer to Qn 3: Check for any obvious issues with the observations 
# (keep in mind the minimum & maximum possible values for each test/subtest).

act_2017.describe()
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean        0.652549  20.931373  21.182353  22.013725  21.041176  21.519608
# std         0.321408   2.353677   1.981989   2.067271   3.182463   2.020695
# min         0.080000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%         0.310000  19.000000  19.400000  20.450000  19.900000  19.800000
# 50%         0.690000  20.700000  20.900000  21.800000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.150000  22.750000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %% [markdown]
# **Found act_2017 participation and science is too low**
#
# found act scores in ([*source*](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf))  mean score for Maryland[Science] = 23.4

# %%
# Found Maryland having Science = 2.3 

act_2017[act_2017['Science'] == 2.300000]
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 20  Maryland           0.28     23.3  23.1     24.2      2.3       23.6

# %%
act_2017[act_2017['Science'] == 2.300000].loc[:,'Composite']
# Out:
# 20    23.6
# Name: Composite, dtype: float64

# %%
# Based on reasoning, work backwards from mean to get individual score and cross check with source 
comp = act_2017[act_2017['Science'] == 2.300000].loc[:,'Composite']
Eng = act_2017[act_2017['Science'] == 2.300000].loc[:,'English']
Math = act_2017[act_2017['Science'] == 2.300000].loc[:,'Math']
Reading = act_2017[act_2017['Science'] == 2.300000].loc[:,'Reading']

Sci = (comp * 4) - Eng - Math - Reading

# verify close to actual source - replace this value into dataframe
Sci
# Out:
# 20    23.8
# dtype: float64

# %%
act_2017.loc[act_2017['State'] == 'Maryland','Science'] = Sci

# %% [markdown]
# **Found sat_2017 math is too low**
#
# found act scores in ([*source*](https://reports.collegeboard.org/pdf/2017-maryland-sat-suite-assessments-annual-report.pdf)) mean score for Maryland[Math] = 524

# %%
# check for max and min for ACT 2017 

sat_2017.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  547.627451
# std         0.352766                           45.666901   84.909119
# min         0.020000                          482.000000   52.000000
# 25%         0.040000                          533.500000  522.000000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
sat_2017.loc[sat_2017['Math'] == 52.000000,:]
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536    52   1060

# %%
# Replacing value via taking (total - ebrw)
sat_2017.loc[sat_2017['Math'] == 52.000000, 'Math'] = (1060  - 536)

# %%
sat_2017[sat_2017.State == 'Maryland']
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536   524   1060

# %%
check_dups_missing(sat_2017,'State',us_states,'state')
# Out:
# Df has 1 of missing data
# Df has 0 of duplicated data
#
# Array of missing data under column: "State"
# Missing data array: ['District of Columbia'] at Index: [8]
#
# No duplicated dataframe

# %% [markdown]
# **merge act_2017 and sat_2017**

# %%
combined_2017 = pd.merge(sat_2017, act_2017, how='outer', indicator='Exist', on = 'State')

# %%
new_column = ['state','sat_prt','sat_erw','sat_math','sat_total','act_prt','act_eng','act_math',
              'act_read','act_sci','act_comp','exist']

combined_2017.columns = new_column
combined_2017.drop('exist', axis = 1,inplace = True)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %%
# Read csv file for 2018 data

act_2018 = pd.read_csv('Data/act_2018.csv')
sat_2018 = pd.read_csv('Data/sat_2018.csv')

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# participation found to be object
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# participation is object

sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
dict_sat_col = {
    'State':'state',
    'Participation': 'prt',
    'Evidence-Based Reading and Writing': 'erw',
    'Math': 'math',
    'Total':'total'   
}

# %%
dict_act_col = {
    'State':'state',
    'Participation':'prt',
    'Composite':'comp'
}

# %%
#Rename small caps

act_2018.rename(columns = dict_act_col, inplace = True )
sat_2018.rename(columns = dict_sat_col, inplace = True )

# %%
# convert percentage to float
filelist = [act_2018,sat_2018]

for file in filelist:
    file['prt'] = file['prt'].apply(lambda x: remove_percent_conv_float(x))

# %%
file = sat_2018
# convert int to float
file['erw'] = file['erw'].apply(lambda x: float(x))

file['math'] = file['math'].apply(lambda x: float(x))
file['total'] = file['total'].apply(lambda x: float(x))

# %%
check_dups_missing(act_2018,'state',us_states,'state')
# Out:
# Df has 1 of missing data
# Df has 1 of duplicated data
#
# Array of missing data under column: "state"
# Missing data array: ['District of columbia'] at Index: [8]
#
# Array of duplicated data under column: "state"
# Duplicated words: ['Maine'] at Index: [20]

# %%
# Dropping Maine - duplicate at index: 20
act_2018.drop(index = 20, inplace = True)
act_2018.reset_index(drop=True, inplace=True)

# %% [markdown]
# **Check min max of ACT_2018**

# %%
# Answer to Qn 3: 3. Check for any obvious issues with the observations 
# (keep in mind the minimum & maximum possible values for each test/subtest).

act_2018.describe()
# Out:
#              prt       comp
# count  51.000000  51.000000
# mean    0.617255  21.496078
# std     0.340371   2.111583
# min     0.070000  17.700000
# 25%     0.285000  19.950000
# 50%     0.660000  21.300000
# 75%     1.000000  23.650000
# max     1.000000  25.600000

# %%
sat_2018.describe()
# Out:
#              prt         erw        math        total
# count  51.000000   51.000000   51.000000    51.000000
# mean    0.457451  563.686275  556.235294  1120.019608
# std     0.373143   47.502627   47.772623    94.155083
# min     0.020000  480.000000  480.000000   977.000000
# 25%     0.045000  534.500000  522.500000  1057.500000
# 50%     0.520000  552.000000  544.000000  1098.000000
# 75%     0.775000  610.500000  593.500000  1204.000000
# max     1.000000  643.000000  655.000000  1298.000000

# %% [markdown]
# **Merge Merge sat and act for 2018 data**

# %%
# Merge SAT and ACT
combined_2018 = pd.merge(sat_2018, act_2018, how='outer', indicator='Exist', on = 'state')

# %%
#check if there are any missing data
combined_2018.loc[combined_2018['Exist'] != 'both']
# Out:
#                    state  prt_x    erw   math  total  prt_y  comp       Exist
# 8   District of Columbia   0.92  497.0  480.0  977.0    NaN   NaN   left_only
# 51  District of columbia    NaN    NaN    NaN    NaN   0.32  23.6  right_only

# %%
# define function that tells us difference between two strings under one column
## we reference index as it will not have issues calling
### function considers (number of chars) and (the char by incrementing index)

def get_char_diff(df, col, L_index, R_index):
    # set variable to store length of char for left and right 
    # need to call out values else will return series 
    # need to call out [0] for values else will return numpy array
    L_numchar = len(df.loc[[L_index],col].values[0])
    R_numchar = len(df.loc[[R_index],col].values[0])
    
    # if both numbers the same -->> for loop 
    if L_numchar == R_numchar:
        
        # enumerate to call same index for right table
        for num, left_letter in enumerate (df.loc[[L_index],col].values[0]):
            right_letter = df.loc[[R_index],col].values[0][num]
            if right_letter != left_letter:
                print(f'Left list has char: "{left_letter}" at column index: {num}')
                print(f'Right list has char: "{right_letter}" at column index: {num}')
    else:
        print(f'Left data has {L_numchar} characters')
        print(f'Right data has {R_numchar} characters')

# %%
#applying function get_char_diff

get_char_diff(combined_2018,'state',8,51)
# Out:
# Left list has char: "C" at column index: 12
# Right list has char: "c" at column index: 12

# %%
# Edit Column for act_2018 to match with sat_2018

act_2018.loc[act_2018['state'] == 'District of columbia','state'] = "District of Columbia"

# %%
# Merge again
combined_2018 = pd.merge(sat_2018, act_2018, how='outer', indicator='Exist', on = 'state')

#check if there are any missing data
combined_2018.loc[combined_2018['Exist'] != 'both']
# Out:
# Empty DataFrame
# Columns: [state, prt_x, erw, math, total, prt_y, comp, Exist]
# Index: []

# %%
combined_2018.columns
# Out:
# Index(['state', 'prt_x', 'erw', 'math', 'total', 'prt_y', 'comp', 'Exist'], dtype='object')

# %%
# rename columns 
new_column = ['state','sat_prt','sat_erw','sat_math','sat_total','act_prt','act_comp','exist']

combined_2018.columns = new_column
combined_2018.drop('exist', axis = 1,inplace = True)

# %% [markdown]
# ## Merge with Income

# %%
# Set columns 
set_column = ['state', 'inc_cap']
us_income.columns = set_column

# %%
us_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   state    51 non-null     object
#  1   inc_cap  51 non-null     object
# dtypes: object(2)
# memory usage: 944.0+ bytes

# %%
# remove letters return float for inc_cap
us_income['inc_cap'] = us_income['inc_cap'].apply(remove_str_conv_float)

# %%
us_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   state    51 non-null     object
#  1   inc_cap  51 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 944.0+ bytes

# %%
# Merge sat and act for 2017 data
combine_income_2017 = pd.merge(combined_2017, us_income, how = 'outer', indicator = 'Exist', on = 'state')

#check if there are any missing data
combine_income_2017.loc[combine_income_2017['Exist'] != 'both']
# Out:
#                    state  sat_prt  sat_erw  sat_math  sat_total  act_prt  \
# 8   District of Columbia      1.0    482.0     468.0      950.0     0.32
# 51                    DC      NaN      NaN       NaN        NaN      NaN
#
#     act_eng  act_math  act_read  act_sci  act_comp  inc_cap       Exist
# 8      24.4      23.5      24.9     23.5      24.2      NaN   left_only
# 51      NaN       NaN       NaN      NaN       NaN  71496.0  right_only

# %%
# Edit inc per capita for index 8 and remove index 51 as its the same 
combine_income_2017.loc[combine_income_2017['state'] == 'District of Columbia','inc_cap'] = 71496.0

# Dropping DC row
combine_income_2017.drop(index = 51, inplace = True)
combine_income_2017.reset_index(drop=True, inplace=True)

# %%
combine_income_2017.index[50]
# Out:
# 50

# %%
# Drop Exist column 
combine_income_2017.drop('Exist', axis = 1,inplace = True)

# %%
# Merge sat and act for 2018 data
final_income = pd.merge(combine_income_2017, combined_2018, how = 'outer', indicator = 'Exist', on = 'state')

# %%
#check if there are any missing data
final_income.loc[final_income['Exist'] != 'both']
# Out:
# Empty DataFrame
# Columns: [state, sat_prt_x, sat_erw_x, sat_math_x, sat_total_x, act_prt_x, act_eng, act_math, act_read, act_sci, act_comp_x, inc_cap, sat_prt_y, sat_erw_y, sat_math_y, sat_total_y, act_prt_y, act_comp_y, Exist]
# Index: []

# %%
def changetitle(columns):
    return [col.replace("_x", "_2017") if '_x' in col else col.replace("_y", "_2018") if '_y' in col else col for col in columns]

# %%
final_income.columns = changetitle(final_income.columns)
final_income.drop('Exist', axis = 1, inplace = True)
final_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           51 non-null     object
#  1   sat_prt_2017    51 non-null     float64
#  2   sat_erw_2017    51 non-null     float64
#  3   sat_math_2017   51 non-null     float64
#  4   sat_total_2017  51 non-null     float64
#  5   act_prt_2017    51 non-null     float64
#  6   act_eng         51 non-null     float64
#  7   act_math        51 non-null     float64
#  8   act_read        51 non-null     float64
#  9   act_sci         51 non-null     float64
#  10  act_comp_2017   51 non-null     float64
#  11  inc_cap         51 non-null     float64
#  12  sat_prt_2018    51 non-null     float64
#  13  sat_erw_2018    51 non-null     float64
#  14  sat_math_2018   51 non-null     float64
#  15  sat_total_2018  51 non-null     float64
#  16  act_prt_2018    51 non-null     float64
# ...

# %%
# getting 25%, 50% and 75% mark 
final_income.describe()['inc_cap']
# Out:
# count       51.000000
# mean     46929.352941
# std       7833.806614
# min      35444.000000
# 25%      41139.000000
# 50%      45002.000000
# 75%      50843.500000
# max      71496.000000
# Name: inc_cap, dtype: float64

# %%
# define function that categorises floats into 4 Categories
def categorise_income(columns):
    if columns < 41000:
        return '<$41,000'

    elif columns >= 41000 and columns <= 45000:
        return '\\$41,000-$45,000'

    elif columns >= 45000 and columns <= 51000:
        return '\\$45,000-$51,000'
    
    elif columns > 51000:
        return '>$51,000'
            
    return str(columns)

# %%
# to bring in category of income into dataframe 

final_income['cat_inc'] = final_income['inc_cap'].apply(lambda x: categorise_income(x))

# %%
# define function of average between two columns and 

def ave_between_two_cols(df,new_col,col1,col2):
    # make list
    col_list = [col1,col2]
    
    # create new column with mean of two col1,col2 
    df[new_col] = df[col_list].sum(axis = 1)/2
    
    #returns df
    return df

# %%
# getting two more columns for sat_ave and Act_ave across two years 

final_income = ave_between_two_cols(final_income,'sat_ave','sat_total_2017','sat_total_2018')
final_income = ave_between_two_cols(final_income,'act_ave','act_comp_2017','act_comp_2018')

# %%
# rename columns for final_income

final_income.columns = ['state', 'sat_prt_2017', 'sat_erw_2017', 'sat_math_2017',
       'sat_total_2017', 'act_prt_2017', 'act_eng_2017', 'act_math_2017', 'act_read_2017',
       'act_sci_2017', 'act_comp_2017', 'inc_cap', 'sat_prt_2018', 'sat_erw_2018',
       'sat_math_2018', 'sat_total_2018', 'act_prt_2018', 'act_comp_2018',
       'cat_inc', 'sat_ave', 'act_ave']

# %%
# get_dummies to make cat_inc numerised  

final_income = pd.get_dummies(final_income, columns = ['cat_inc'], drop_first = False)
final_income['cat_inc'] = final_income['inc_cap'].apply(lambda x: categorise_income(x))

# %%
# Answer to question 1 

combined_2017.head()
combined_2018.head()
final_income.head()
# Out:
#         state  sat_prt_2017  sat_erw_2017  sat_math_2017  sat_total_2017  \
# 0     Alabama          0.05         593.0          572.0          1165.0
# 1      Alaska          0.38         547.0          533.0          1080.0
# 2     Arizona          0.30         563.0          553.0          1116.0
# 3    Arkansas          0.03         614.0          594.0          1208.0
# 4  California          0.53         531.0          524.0          1055.0
#
#    act_prt_2017  act_eng_2017  act_math_2017  act_read_2017  act_sci_2017  \
# 0          1.00          18.9           18.4           19.7          19.4
# 1          0.65          18.7           19.8           20.4          19.9
# 2          0.62          18.6           19.8           20.1          19.8
# 3          1.00          18.9           19.0           19.7          19.5
# 4          0.31          22.5           22.7           23.1          22.2
#
#    ...  sat_total_2018  act_prt_2018  act_comp_2018  sat_ave  act_ave  \
# ...

# %%
# Answer to QN 2 -->> function to check for null/missing values in dataframe
def check_for_null(df):
    noproblem = True
    for i in df.columns:
        if (len(df[df[i].isnull()])!=0 or len(df[df[i]==0])!=0):
            print(f"{i} has {len(df[df[i].isnull()])} 'null' values and {len(df[df[i]==0])} values remaining")
            noproblem = False
            
    if noproblem:
        print('OK')
    else:
        print('Not OK')

# %%
filter_dummyzeros = ['cat_inc_<$41,000','cat_inc_>$51,000', 'cat_inc_\\$41,000-$45,000','cat_inc_\\$45,000-$51,000']
list_of_df = [combined_2017, combined_2018, final_income.set_index(filter_dummyzeros)]

for df in list_of_df:
    check_for_null(df)
# Out:
# OK
# OK
# OK

# %%
# Question 11: Save your cleaned and merged dataframes as csv files.

final_income.to_csv('final_income.csv', index = False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|final_income|Names of all US states and the District of Columbia|
# |**sat_prt_2017**|*float*|final_income|The percentage of 2017 graduating students who took SAT ( units percent to two decimal places, 0.05 means 5%)|
# |**sat_erw_2017**|*float*|final_income|The mean score of SAT Evidence-Based-Reading and Writing (ERW) category in 2017 (Score range from 200-800)|
# |**sat_math_2017**|*float*|final_income|The mean score of SAT Math of the in 2017 (Score range from 200-800)|
# |**sat_total_2017**|*float*|final_income|The mean total score of SAT combining Math and ERW (Score range from 200-800)|
# |**act_prt_2017**|*float*|final_income|The percentage of 2017 graduating students who took ACT ( units percent to two decimal places, 0.05 means 5%)|
# |**act_eng_2017**|*float*|final_income|The mean score of ACT English score (Score range from 1-36)|
# |**act_math_2017**|*float*|final_income|The mean score of ACT Math score (Score range from 1-36)|
# |**act_read_2017**|*float*|final_income|The mean score of ACT Reading score (Score range from 1-36)|
# |**act_sci_2017**|*float*|final_income|The mean score of ACT Science score (Score range from 1-36)|
# |**act_comp_2017**|*float*|final_income|The mean total score of ACT combining English, Math, Reading and Science (Score range from 1-36)|
# |**sat_prt_2018**|*float*|final_income|The percentage of 2018 graduating students who took SAT ( units percent to two decimal places, 0.05 means 5%)|
# |**sat_erw_2018**|*float*|final_income|The mean score of SAT Evidence-Based-Reading and Writing (ERW) category in 2017 (Score range from 200-800)|
# |**sat_math_2018**|*float*|final_income|The mean score of SAT Math of the in 2018 (Score range from 200-800)|
# |**sat_total_2018**|*float*|final_income|The mean total score of SAT combining Math and ERW (Score range from 200-800)|
# |**act_prt_2018**|*float*|final_income|The percentage of 2018 graduating students who took ACT ( units percent to two decimal places, 0.05 means 5%)|
# |**act_eng_2018**|*float*|final_income|The mean score of ACT English score (Score range from 1-36)|
# |**act_math_2018**|*float*|final_income|The mean score of ACT Math score (Score range from 1-36)|
# |**act_read_2018**|*float*|final_income|The mean score of ACT Reading score (Score range from 1-36)|
# |**act_sci_2018**|*float*|final_income|The mean score of ACT Science score (Score range from 1-36)|
# |**act_comp_2018**|*float*|final_income|The mean total score of ACT combining English, Math, Reading and Science (Score range from 1-36)|
# |**inc_cap**|*float*|final_income|The mean income per capita by States 2015 (Income range from \\$35444 - $71496)|
# |**sat_ave**|*float*|final_income|The average SAT score between 2017 and 2018 (Income range from 963.5 - 1296.5)|
# |**act_ave**|*float*|final_income|The average ACT score between 2017 and 2018 (Income range from 25.45 - 25.45)|
# |**cat_inc**|*Object*|final_income|The Income category by State (Contains four categories split by 25%, 50% and 75%)|
# |**cat_inc_<\\$41,000**|*Object*|final_income|Accounts for states under category, whereby 0 is not in category while 1 indicates state under category of \\$41000 or less (Binary values indicating income <\\$41,000)|
# |**cat_inc_<\\$41,000-\\$45,000**|*Object*|final_income|Accounts for states under category, whereby 0 is not in category while 1 indicates state under category of between 41000 to 45000 (Binary values indicating income >\\$41,000-\\$45,000)
# |**cat_inc_<\\$45,000-\\$51,000**|*Object*|final_income|Accounts for states under category, whereby 0 is not in category while 1 indicates state under category of 45000 to 51000 or less (Binary values indicating income >\\$45,000-\\$51,000)|
# |**cat_inc_>\\$51,000**|*Object*|final_income|Accounts for states under category, whereby 0 is not in category while 1 indicates state under category of more than 51000 (Binary values indicating income >\\$51,000)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Answer to question 1: show statistics of dataframes
final_income.describe()
# Out:
#        sat_prt_2017  sat_erw_2017  sat_math_2017  sat_total_2017  \
# count     51.000000     51.000000      51.000000       51.000000
# mean       0.398039    569.117647     556.882353     1126.098039
# std        0.352766     45.666901      47.121395       92.494812
# min        0.020000    482.000000     468.000000      950.000000
# 25%        0.040000    533.500000     523.500000     1055.500000
# 50%        0.380000    559.000000     548.000000     1107.000000
# 75%        0.660000    613.000000     599.000000     1212.000000
# max        1.000000    644.000000     651.000000     1295.000000
#
#        act_prt_2017  act_eng_2017  act_math_2017  act_read_2017  act_sci_2017  \
# count     51.000000     51.000000      51.000000      51.000000     51.000000
# mean       0.652549     20.931373      21.182353      22.013725     21.462745
# std        0.321408      2.353677       1.981989       2.067271      1.753392
# ...

# %%
# Answer to question 2:

sd = {col: round(getstdev(final_income[col]),2) for col in final_income.columns if ((final_income[col].dtype == float) | (final_income[col].dtype == 'int64'))} 
sd
# Out:
# {'sat_prt_2017': 0.35,
#  'sat_erw_2017': 45.22,
#  'sat_math_2017': 46.66,
#  'sat_total_2017': 91.58,
#  'act_prt_2017': 0.32,
#  'act_eng_2017': 2.33,
#  'act_math_2017': 1.96,
#  'act_read_2017': 2.05,
#  'act_sci_2017': 1.74,
#  'act_comp_2017': 2.0,
#  'inc_cap': 7756.62,
#  'sat_prt_2018': 0.37,
#  'sat_erw_2018': 47.03,
#  'sat_math_2018': 47.3,
#  'sat_total_2018': 93.23,
#  'act_prt_2018': 0.34,
#  'act_comp_2018': 2.09,
#  'sat_ave': 88.94,
#  'act_ave': 2.02}

# %% [markdown]
# **What are the mean scores for different income groups**
#
# - Observed across income groups, the ACT scores increases on average too as compared to SAT
# - This show disparity in the income during the year 2017, also mentioned in Washingtonpost, ([*source*](https://www.washingtonpost.com/local/education/we-didnt-know-it-was-this-bad-new-act-scores-show-huge-achievement-gaps/2017/09/06/c6397f36-9279-11e7-aace-04b862b2b3f3_story.html))
# - SAT does not have significant trending in income vs SAT scores

# %%
# what is the mean of scores for different income groups (split by four) in 2017
sorted_mean= final_income.groupby('cat_inc')[['sat_total_2017','act_comp_2017']].mean().T
sorted_mean = sorted_mean[['<$41,000', '\$41,000-$45,000', '\$45,000-$51,000', '>$51,000']]
round(sorted_mean,2)
# Out:
# cat_inc         <$41,000  \$41,000-$45,000  \$45,000-$51,000  >$51,000
# sat_total_2017   1131.85           1135.17           1152.23   1085.85
# act_comp_2017      20.11             20.93             21.86     23.14

# %%
# what is the mean of scores for different income groups (split by four) in 2017
sorted_mean= final_income.groupby('cat_inc')[['sat_total_2018','act_comp_2018']].mean().T
sorted_mean = sorted_mean[['<$41,000', '\$41,000-$45,000', '\$45,000-$51,000', '>$51,000']]
round(sorted_mean,2)
# Out:
# cat_inc         <$41,000  \$41,000-$45,000  \$45,000-$51,000  >$51,000
# sat_total_2018   1105.92           1142.25           1127.46   1106.15
# act_comp_2018      20.02             20.61             22.18     23.11

# %% [markdown]
# **Consistent lowest performing states in 2017,2018**
#
# - The worst performing states for ACTs are ['Nevada', 'Mississippi', 'South Carolina', 'Hawaii'].
# - Found Nevada to have lowest scores for both years. The school has just started making 11th graders to take ACT starting from 2016, hence indicating that the school may not be ready.
# - Most of these states fall under lower income group lower than the statewide median value for ACTs
# - The worst performing states are for SATs are ['District of Columbia', 'Delaware', 'Idaho'], of which Idaho belongs to the lower income group.

# %%
# bottom 5 least performing in ACT 2017
a1 = final_income.sort_values('act_comp_2017', ascending=True).head(5).loc[:,['state', 'act_comp_2017']]
# bottom 5 least performing in ACT 2018
a2 = final_income.sort_values('act_comp_2018', ascending=True).head(5).loc[:,['state', 'act_comp_2018']]

a3 = pd.merge(a1,a2,on='state')
print(f"List of states consistently in bottom ACT test scores: {[i for i in a3['state']]}")

# of the 4 states, which belongs to the lower income group <45000 and below 
a4 = final_income[final_income['inc_cap'] < 45000]
a5 = pd.merge(a3,a4,on='state')
print(f"Out of the {len(a3)} states, {len(a5)} belongs to the lower income group mainly: {[i for i in a5['state']]}")

# table showing differences in minority percentage between these 5 states and statewide mean

mean_diff_2017 = (final_income[['act_comp_2017','act_comp_2018']].mean()- a3['act_comp_2017'].mean())[0]
mean_diff_2018 = (final_income[['act_comp_2017','act_comp_2018']].mean()- a3['act_comp_2017'].mean())[1]


print(f'Mean score difference between {len(a5)} states vs statewide average in 2017 is: {round(mean_diff_2017,2)}')
print(f'Mean score difference between {len(a5)} states vs statewide average in 2018 is: {round(mean_diff_2018,2)}')
# Out:
# List of states consistently in bottom ACT test scores: ['Nevada', 'Mississippi', 'South Carolina', 'Hawaii']
# Out of the 4 states, 3 belongs to the lower income group mainly: ['Nevada', 'Mississippi', 'South Carolina']
# Mean score difference between 3 states vs statewide average in 2017 is: 2.99
# Mean score difference between 3 states vs statewide average in 2018 is: 2.97

# %%
# bottom 5 least performing in SAT 2017
a1 = final_income.sort_values('sat_total_2017', ascending=True).head(5).loc[:,['state', 'sat_total_2017']]
# bottom 5 least performing in SAT 2018
a2 = final_income.sort_values('sat_total_2018', ascending=True).head(5).loc[:,['state', 'sat_total_2018']]

a3 = pd.merge(a1,a2,on='state')
print(f"List of states consistently in bottom SAT test scores: {[i for i in a3['state']]}")

# of the 4 states, which belongs to the lower income group <45000 and below 
a4 = final_income[final_income['inc_cap'] < 45000]
a5 = pd.merge(a3,a4,on='state')
print(f"Out of the {len(a3)} states, {len(a5)} belongs to the lower income group mainly: {[i for i in a5['state']]}")

# table showing differences in minority percentage between these 5 states and statewide mean

mean_diff_2017 = (final_income[['sat_total_2017','sat_total_2018']].mean()- a3['sat_total_2017'].mean())[0]
mean_diff_2018 = (final_income[['sat_total_2017','sat_total_2018']].mean()- a3['sat_total_2017'].mean())[1]


print(f'Mean score difference between {len(a5)} states vs statewide average in 2017 is: {round(mean_diff_2017,2)}')
print(f'Mean score difference between {len(a5)} states vs statewide average in 2018 is: {round(mean_diff_2018,2)}')
# Out:
# List of states consistently in bottom SAT test scores: ['District of Columbia', 'Delaware', 'Idaho']
# Out of the 3 states, 1 belongs to the lower income group mainly: ['Idaho']
# Mean score difference between 1 states vs statewide average in 2017 is: 142.43
# Mean score difference between 1 states vs statewide average in 2018 is: 136.35

# %% [markdown]
# **From the lowest 5 states, what is the lowest scoring subject in ACT**
#
# - Found English have the lowest mean score amongst the 5 lowest scoring States

# %%
# aggregate by mean,median and std across all incomes
final_income[['act_eng_2017','act_math_2017', 'act_read_2017', 'act_sci_2017']].agg(['mean','median','std','count'])
# Out:
#         act_eng_2017  act_math_2017  act_read_2017  act_sci_2017
# mean       20.931373      21.182353      22.013725     21.462745
# median     20.700000      20.900000      21.800000     21.300000
# std         2.353677       1.981989       2.067271      1.753392
# count      51.000000      51.000000      51.000000     51.000000

# %%
# aggregate by mean,median and std across 5 lowest scoring states 
five_lowest = final_income.sort_values(['act_ave','inc_cap'], ascending = (True,True))[['act_eng_2017', 'act_math_2017',
       'act_read_2017', 'act_sci_2017']].head(5)

round(five_lowest.agg(['mean','median','std','count']),2)
# Out:
#         act_eng_2017  act_math_2017  act_read_2017  act_sci_2017
# mean           17.52          18.64          18.96         18.90
# median         17.80          18.60          19.10         18.90
# std             0.73           0.60           0.56          0.45
# count           5.00           5.00           5.00          5.00

# %%
# aggregate by mean,median and std across all incomes
final_income[['act_eng_2017','act_math_2017', 'act_read_2017', 'act_sci_2017']].agg(['mean','median','std','count'])
# Out:
#         act_eng_2017  act_math_2017  act_read_2017  act_sci_2017
# mean       20.931373      21.182353      22.013725     21.462745
# median     20.700000      20.900000      21.800000     21.300000
# std         2.353677       1.981989       2.067271      1.753392
# count      51.000000      51.000000      51.000000     51.000000

# %%
# aggregate by mean,median and std across all incomes

five_lowest_sat = final_income.sort_values(['sat_total_2018','inc_cap'], ascending = (True,True))[['sat_math_2017', 'sat_erw_2017', 'sat_total_2017', 'sat_total_2018']].head(5)

round(five_lowest_sat.agg(['mean','median','std','count']),2)
# Out:
#         sat_math_2017  sat_erw_2017  sat_total_2017  sat_total_2018
# mean           519.00        536.00         1055.00          997.00
# median         493.00        513.00         1005.00          999.00
# std             57.25         56.48          113.42           12.14
# count            5.00          5.00            5.00            5.00

# %% [markdown]
# **Check on participation rate changes over 2017 to 2018**
#
# Colorado and Illinois has huge reduction of participation rate that from 2017 to 2018, mainly due to the change in test requirement in 2017 from ACT to SAT
# (Colorado - [*source*](https://testive.com/colorado-sat-change-2017/))
# (Illinois - [*source*](https://testive.com/illinois/))

# %%
act_comparison_part = final_income[['state', 'act_prt_2017', 'act_prt_2018','sat_prt_2017', 'sat_prt_2018']]
act_comparison_part['act_diff'] = ((act_comparison_part.iloc[:,2] - act_comparison_part.iloc[:,1])/act_comparison_part.iloc[:,1]) * 100
act_comparison_part['sat_diff'] = ((act_comparison_part.iloc[:,4] - act_comparison_part.iloc[:,3])/act_comparison_part.iloc[:,3]) * 100

# ascending order by difference in act participation across 2017 and 2018
act_comparison_part.sort_values('act_diff', ascending = True).head()
# Out:
#            state  act_prt_2017  act_prt_2018  sat_prt_2017  sat_prt_2018  \
# 5       Colorado          1.00          0.30          0.11          1.00
# 13      Illinois          0.93          0.43          0.09          0.99
# 1         Alaska          0.65          0.33          0.38          0.43
# 39  Rhode Island          0.21          0.15          0.71          0.97
# 22      Michigan          0.29          0.22          1.00          1.00
#
#      act_diff     sat_diff
# 5  -70.000000   809.090909
# 13 -53.763441  1000.000000
# 1  -49.230769    13.157895
# 39 -28.571429    36.619718
# 22 -24.137931     0.000000

# %%
# descending order by difference in act participation across 2017 and 2018
act_comparison_part.sort_values('act_diff', ascending = False).head()
# Out:
#        state  act_prt_2017  act_prt_2018  sat_prt_2017  sat_prt_2018  \
# 35      Ohio          0.75          1.00          0.12          0.18
# 27  Nebraska          0.84          1.00          0.03          0.03
# 20  Maryland          0.28          0.31          0.69          0.76
# 2    Arizona          0.62          0.66          0.30          0.29
# 37    Oregon          0.40          0.42          0.43          0.48
#
#      act_diff   sat_diff
# 35  33.333333  50.000000
# 27  19.047619   0.000000
# 20  10.714286  10.144928
# 2    6.451613  -3.333333
# 37   5.000000  11.627907

# %%
# ascending order by difference in SAT participation across 2017 and 2018
act_comparison_part.sort_values('sat_diff', ascending = True).head()
# Out:
#                    state  act_prt_2017  act_prt_2018  sat_prt_2017  \
# 9                Florida          0.73          0.66          0.83
# 28                Nevada          1.00          1.00          0.26
# 8   District of Columbia          0.32          0.32          1.00
# 2                Arizona          0.62          0.66          0.30
# 50               Wyoming          1.00          1.00          0.03
#
#     sat_prt_2018  act_diff   sat_diff
# 9           0.56 -9.589041 -32.530120
# 28          0.23  0.000000 -11.538462
# 8           0.92  0.000000  -8.000000
# 2           0.29  6.451613  -3.333333
# 50          0.03  0.000000   0.000000

# %%
# descending order by difference in SAT participation across 2017 and 2018
act_comparison_part.sort_values('sat_diff', ascending = False).head()
# Out:
#             state  act_prt_2017  act_prt_2018  sat_prt_2017  sat_prt_2018  \
# 13       Illinois          0.93          0.43          0.09          0.99
# 5        Colorado          1.00          0.30          0.11          1.00
# 48  West Virginia          0.69          0.65          0.14          0.28
# 3        Arkansas          1.00          1.00          0.03          0.05
# 35           Ohio          0.75          1.00          0.12          0.18
#
#      act_diff     sat_diff
# 13 -53.763441  1000.000000
# 5  -70.000000   809.090909
# 48  -5.797101   100.000000
# 3    0.000000    66.666667
# 35  33.333333    50.000000

# %% [markdown]
# **Check on score changes over 2017 to 2018**
#
# Colorado sees biggest jump in ACT grades, while SAT scores dropped by similar percentage of 14.6%. This is likely due to an effect whereby lower participation rates have average scores reflective of smarter and better prepared students who voluntarily taking the test.
# (Colorado - [*source*](https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01))

# %%
act_comparison_score = final_income[['state','act_comp_2017', 'act_comp_2018', 'sat_total_2017', 'sat_total_2018']]
act_comparison_score['act_diff'] = ((act_comparison_score.iloc[:,2] - act_comparison_score.iloc[:,1])/act_comparison_score.iloc[:,1]) * 100
act_comparison_score['sat_diff'] = ((act_comparison_score.iloc[:,4] - act_comparison_score.iloc[:,3])/act_comparison_score.iloc[:,3]) * 100

# ascending order by difference in act scores across 2017 and 2018
act_comparison_score.sort_values('act_diff', ascending = True).head()
# Out:
#                    state  act_comp_2017  act_comp_2018  sat_total_2017  \
# 35                  Ohio           22.0           20.3          1149.0
# 27              Nebraska           21.4           20.1          1253.0
# 20              Maryland           23.6           22.5          1060.0
# 2                Arizona           19.7           19.2          1116.0
# 8   District of Columbia           24.2           23.6           950.0
#
#     sat_total_2018  act_diff  sat_diff
# 35          1099.0 -7.727273 -4.351610
# 27          1252.0 -6.074766 -0.079808
# 20          1080.0 -4.661017  1.886792
# 2           1149.0 -2.538071  2.956989
# 8            977.0 -2.479339  2.842105

# %%
# descending order by difference in act scores across 2017 and 2018
act_comparison_score.sort_values('act_diff', ascending = False).head()
# Out:
#           state  act_comp_2017  act_comp_2018  sat_total_2017  sat_total_2018  \
# 5      Colorado           20.8           23.9          1201.0          1025.0
# 13     Illinois           21.4           23.9          1115.0          1019.0
# 1        Alaska           19.8           20.8          1080.0          1106.0
# 45      Vermont           23.6           24.1          1114.0          1120.0
# 6   Connecticut           25.2           25.6          1041.0          1053.0
#
#      act_diff   sat_diff
# 5   14.903846 -14.654455
# 13  11.682243  -8.609865
# 1    5.050505   2.407407
# 45   2.118644   0.538600
# 6    1.587302   1.152738

# %%
# descending order by difference in act scores across 2017 and 2018
act_comparison_score.sort_values('sat_diff', ascending = False).head()
# Out:
#                    state  act_comp_2017  act_comp_2018  sat_total_2017  \
# 9                Florida           19.8           19.9          1017.0
# 30            New Jersey           23.9           23.7          1056.0
# 2                Arizona           19.7           19.2          1116.0
# 8   District of Columbia           24.2           23.6           950.0
# 1                 Alaska           19.8           20.8          1080.0
#
#     sat_total_2018  act_diff  sat_diff
# 9           1099.0  0.505051  8.062930
# 30          1094.0 -0.836820  3.598485
# 2           1149.0 -2.538071  2.956989
# 8            977.0 -2.479339  2.842105
# 1           1106.0  5.050505  2.407407

# %%
# ascending order by difference in act scores across 2017 and 2018
act_comparison_score.sort_values('sat_diff', ascending = True).head()
# Out:
#             state  act_comp_2017  act_comp_2018  sat_total_2017  \
# 44           Utah           20.3           20.4          1238.0
# 5        Colorado           20.8           23.9          1201.0
# 13       Illinois           21.4           23.9          1115.0
# 48  West Virginia           20.4           20.3          1086.0
# 11         Hawaii           19.0           18.9          1085.0
#
#     sat_total_2018   act_diff   sat_diff
# 44          1010.0   0.492611 -18.416801
# 5           1025.0  14.903846 -14.654455
# 13          1019.0  11.682243  -8.609865
# 48           999.0  -0.490196  -8.011050
# 11          1010.0  -0.526316  -6.912442

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ## **Observations**
#
# 1) Generally states with higher participation rates for SATs will have a negative correlation with participation rates for ACTs, with values of -0.76 to -0.87 across 2 years. This suggest it might be attributed by mandate of each state to do either one of the test ([*source*](https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/))
#
# 2) Looking into correlation between income and SATs/ACTs, SAT does not have strong association with income whereas ACT does has a positive correlation of 0.62 based on the average ACT scores from two years. From ACT Research ([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf)), ACT scores are showing disparity between the rich and the poorer states.
#
# 3) SAT scores does not have strong correlation with income (-0.14 ~ -0.27)
#
# 4) ACT scores have a stronger positive correlation with income (0.44 ~ 0.62)
#
# 5) Participation rate has high negative correlation with scores across both test, meaning the higher the participation rate, the lower the scores.
# - SAT (~-0.8)
# - ACT (~-0.8)

# %%
# to filter out dummycolumns 
temp_final = final_income[['state', 'sat_prt_2017', 'sat_erw_2017', 'sat_math_2017',
       'sat_total_2017', 'act_prt_2017', 'act_eng_2017', 'act_math_2017',
       'act_read_2017', 'act_sci_2017', 'act_comp_2017', 'inc_cap',
       'sat_prt_2018', 'sat_erw_2018', 'sat_math_2018', 'sat_total_2018',
       'act_prt_2018', 'act_comp_2018', 'sat_ave', 'act_ave']]
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(temp_final.corr(), dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20, 230, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(temp_final.corr(), mask=mask, cmap=cmap, vmax=0.7,
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.5}, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(temp_final, kind='reg')

# %% [markdown]
# **Analysis SAT/ACT scores vs Income per capita**
#
# - Noted that the SAT score shows a weak negative association with the income per capita
# - ACT has relative strong correlation with income
# - need to split by participation rate to futher dive down and check on the SAT correlation to income

# %%
# establish figure size 
plt.figure(figsize = (17,5))


# Generate a custom diverging colormap
cmap = sns.diverging_palette(360, 150, s=100, l=55, n=9, as_cmap=True)


# create subplot of 1 row, 2 columns showing SATs and ACT side to side

ax1 = plt.subplot(1,2,1)
ax1 = plt.scatter(
    x = 'inc_cap',
    y = 'sat_ave', 
    data = final_income,
    c = 'sat_prt_2018',
    linewidths = 2,
    cmap = cmap
    
)

# set up x and y axis for linear line 
x = final_income['inc_cap'].values
y = final_income['sat_ave'].values

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)



# Label for X and Y left graph
plt.xlabel("Income per capita")
plt.ylabel("SATs Total Score 2018")
plt.title('SAT Vs $ Income per Capita')
cbar = plt.colorbar(ax1)
cbar.set_label('SAT Participation rate %', rotation=270)

# create second plot column 2

ax2 = plt.subplot(1,2,2)
ax2.set_title('GOOG Low Prices')
ax2 = plt.scatter(
    x = 'inc_cap',
    y = 'act_ave', 
    data = final_income ,
    c = 'act_prt_2018',
    linewidths = 2,
    cmap = cmap
    
)

# set up x and y axis for linear line 
x2 = final_income['inc_cap'].values
y2 = final_income['act_ave'].values

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x2, y2, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x2+b)

# Label for X and Y left graph
plt.xlabel("Income per capita")
plt.ylabel("ACT Total Score 2018")
plt.title('ACT Vs $ Income per Capita')
cbar = plt.colorbar(ax2)
cbar.set_label('ACT Participation rate %', rotation=270)

# %%
def categorise_part(columns):
    if columns <= 0.2:
        return '<20%'
    else:
        return'>80%'


final_sub_sat = final_income[(final_income['sat_prt_2018'] <= 0.2) | (final_income['sat_prt_2018'] >= 0.8)]   
final_sub_sat['cat_prt'] = final_sub_sat['sat_prt_2018'].apply(categorise_part)

final_sub_act = final_income[(final_income['act_comp_2018'] <= 0.2) | (final_income['act_comp_2018'] >= 0.8)]    
final_sub_act['cat_prt'] = final_sub_act['act_prt_2018'].apply(categorise_part)

ax = sns.lmplot(x="inc_cap",
           y="sat_total_2018",
           hue="cat_prt",
           col="cat_prt",
           col_order =['>80%', '<20%'],
           height=3,
           data=final_sub_sat,
           hue_order = ['>80%', '<20%']);

# Access the figure
fig = ax.fig 

# Add a title to the Figure
ax.fig.suptitle("Income per capita Vs SAT/ACT Scores in 2018", fontsize=15, y = 1.1)

ax.set(xlabel='Income per capita', ylabel='SAT Total Score',)


ax2 = sns.lmplot(x="inc_cap",
           y="act_comp_2018",
           hue="cat_prt",
           col="cat_prt",
           height=3,
           data=final_sub_act,
           hue_order = ['>80%', '<20%']
          
);

ax2.set(xlabel='Income per capita', ylabel='ACT Composite Score',);

# %%
def categorise_part(columns):
    if columns <= 0.2:
        return '<20%'
    
    else:
        return'>80%'

final_sub_sat = final_income[(final_income['sat_prt_2017'] <= 0.2) | (final_income['sat_prt_2017'] >= 0.8)]   
final_sub_sat['cat_prt'] = final_sub_sat['sat_prt_2017'].apply(categorise_part)

final_sub_act = final_income[(final_income['act_comp_2017'] <= 0.2) | (final_income['act_comp_2017'] >= 0.8)]    
final_sub_act['cat_prt'] = final_sub_act['act_prt_2017'].apply(categorise_part)

ax = sns.lmplot(x="inc_cap",
           y="sat_total_2017",
           hue="cat_prt",
           col="cat_prt",
           col_order =['>80%', '<20%'],
           height=3,
           data=final_sub_sat,
           hue_order = ['>80%', '<20%']);

# Access the figure
fig = ax.fig 

# Add a title to the Figure
ax.fig.suptitle("Income per capita Vs SAT/ACT Scores in 2017", fontsize=15, y = 1.1)

ax.set(xlabel='Income per capita', ylabel='SAT Total Score',)


ax2 = sns.lmplot(x="inc_cap",
           y="act_comp_2017",
           hue="cat_prt",
           col="cat_prt",
           col_order =['>80%', '<20%'],      
           height=3,
           data=final_sub_act,
           hue_order = ['>80%', '<20%']
          
);

ax2.set(xlabel='Income per capita', ylabel='ACT Composite Score',);

# %% [markdown]
# **Boxplot by income group vs scores**
#
# - Observed disparity in ACT scores vs income levels of students
# - median for SAT is relatively almost the same across all income groups

# %%
final_subset_2017 = final_income.loc[:,['act_comp_2017', 'cat_inc']]
final_subset_2017.columns = ['score', 'type']
final_subset_2018 = final_income.loc[:,['act_comp_2018', 'cat_inc']]
final_subset_2018.columns = ['score', 'type']

final_list = [final_subset_2017,final_subset_2018]
bx = sns.boxplot(
     data=pd.concat(final_list),
     x='score',
     y='type',
     order = ['<$41,000', '\\$41,000-$45,000','\\$45,000-$51,000','>$51,000' ]
);

bx.set(xlabel = 'ACT Composite Score', ylabel = 'Income Group', title = 'Box plot of ACT scores');

# %%
final_subset_2017 = final_income.loc[:,['sat_total_2017', 'cat_inc']]
final_subset_2017.columns = ['score', 'type']
final_subset_2018 = final_income.loc[:,['sat_total_2018', 'cat_inc']]
final_subset_2018.columns = ['score', 'type']

final_list = [final_subset_2017,final_subset_2018]
bx = sns.boxplot(
     data=pd.concat(final_list),
     x='score',
     y='type',
     order = ['<$41,000', '\\$41,000-$45,000','\\$45,000-$51,000','>$51,000' ]
);

bx.set(xlabel = 'SAT Composite Score', ylabel = 'Income Group', title = 'Box plot of SAT scores');

# %% [markdown]
# **Histogram on Income by States**
#
# - plot shows right skew, indicating very rich states increasing the overall mean as compared to the overall median.
# - Mean of income across states is \\$46929

# %%
sns.histplot(data = final_income, x = 'inc_cap', bins = 13, kde = True)
plt.vlines(
    x = final_income['inc_cap'].mean(),
    ymin = 0,
    ymax = 7,
    color = 'red',
)
mean = final_income['inc_cap'].mean()
print(f'Mean is {mean}');
# Out:
# Mean is 46929.35294117647

# %% [markdown]
# **Analysis SAT/ACT scores vs Income per capita**

# %% [markdown]
# **Comments**
#
# - Noted that there was a cluster of high performing students who took SAT, presumably mostly voluntary as inferred by the rate of participation below 20% across both years 2017 and 2018.

# %%
# set figure size
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=False);
fig.set_size_inches(13, 5);



# plot regplot for ACT 2017,2018 data
sns.regplot(x='act_prt_2017', y='act_comp_2017', data = final_income, ax=ax1);
sns.regplot(x='act_prt_2018', y='act_comp_2018', data = final_income, ax=ax1);
ax1.set_xlabel('ACT participation rate %')
ax1.set_ylabel('ACT Composite Score')

# setting up legend
fig.legend(labels=['2017','2018'], loc = 'center right')

# plot regplot for SAT 2017,2018 data
sns.regplot(x='sat_prt_2017', y='sat_total_2017', data = final_income, ax=ax2);
sns.regplot(x='sat_prt_2018', y='sat_total_2018', data = final_income, ax=ax2);
ax2.set_xlabel('SAT participation rate %')
ax2.set_ylabel('SAT Score');

fig.suptitle('Negative correlation between ACT/SAT Scores vs Participation Rates %', size =15);

# %% [markdown]
# **Histogram plot SAT/ACT scoress across 2017 and 2018**
#
# - Noted huge cluster of high scoring SAT students below participation rate of 20%
#
# - At least 13 states has scored more than 75% percentile for SAT scores across both years

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, sharex=False, kde=False, figsize=(14,7)):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=figsize, sharex=sharex, sharey=True)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns):
        # Calculate mean
        mean = np.mean(dataframe[list_of_columns[i]])
        ax[i].axvline(mean, ls='--', color='crimson')
        
        # Set color of graph according to test type
        if 'act_' in column:
            color = '#E1812C'
        elif 'sat_' in column:
            color = '#3274A1'
        
        sns.histplot(data=dataframe, x=column, color=color, ax=ax[i], kde=kde, bins=9)
        ax[i].set_title(list_of_titles[i] + f' (Mean: {mean:.1f})')
        ax[i].set_xlabel(list_of_xlabels[i])
        # To prevent label duplication
        if i % 2 == 0:
            ax[i].set_ylabel('Number of States')
    
    fig.tight_layout(h_pad = 1.5, w_pad = 1.5)

# %%
subplot_histograms(final_income, ['sat_total_2017', 'act_comp_2017','sat_total_2018', 'act_comp_2018'], 
                   ['SATs Total Score 2017', 'ACTs Composite Score 2017', 'SATs Total Score 2018', 'ACTs Composite Score 2018'], 
                   ['SAT Score', 'ACT Composite Score','SAT Score', 'ACT Composite Score'], sharex=False, kde=True)

# %% [markdown]
# **Histogram plot for participation rates**
#
# - Observed bi-modal distribution on the average scores across 2017 and 2018
# - Distribution seems to be right skewed
# - Mean score for SAT decreased from 2017 to 2018

# %%
subplot_histograms(final_income, ['sat_prt_2017', 'act_prt_2017','sat_prt_2018', 'act_prt_2018'], 
                   ['SATs Participation rate 2017', 'ACTs Participation Rate 2017', 'SATs Participation Rate 2018', 'ACTs Participation Rate 2018'], 
                   ['SAT Participation Rate', 'ACT Participation Rate','SAT Participation Rate', 'ACT Participation Rate'], sharex=False, kde=True)

# %% [markdown]
# **Plot histogram to have glance on least to best performing states based on 2018 alone**

# %%
def plot_hist_against_ave(df,col,title_name,x_axis,y_axis):
    a = final_income[col].mean()
    df = final_income[['state',col]]

    df['comp_diff'] = df[col].map(lambda x: ((x-a)/a) * 100)

    df = df.sort_values('comp_diff')

    x = df['comp_diff']
    y = df['state']

    # establish figure size 
    ax = plt.figure(figsize = (17,17))
    
    # label axis 
    plt.title(title_name, fontsize = 20)
    plt.xlabel(f'{x_axis} (Mean of {round(a,2)})', fontsize = 20)
    plt.ylabel(y_axis, fontsize = 25)

    # plot barh 
    plt.barh(y, x)

# %%
plot_hist_against_ave(final_income,'act_comp_2018','ACT Composite Score 2018', "ACT % diff from mean", 'States')

# %%
plot_hist_against_ave(final_income,'sat_total_2018','SAT Total Score 2018', "SAT % diff from mean", 'States')

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# From this project, we have seen that there is distinct negative correlation between the participations rates and test performance, where the we see the higher the participation rate, the lower the test scores, across SAT/ACT, and across income groups. Its relative to the size of the students taking part in the test, and the volunteering aspect of students who are interested in taking part in the test for further studies in colleges of their choice. We should focus towards providing more test help resources in order to help the weaker states.
#
# In addition, we have concluded that there is a positive correlation between the scores (more for ACT than for SAT) with test performances. A higher percentage of states with lower income has lower scores compared to the average. This is also supported by ACT research team, showed showing difference in test performance by the lower and higher income group.
# ([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf))
#
# From the EDA analysis and visualizations, we have identified that across two years, out of 4 common states identified, 3 of which were from the lower income group taking mandatory ACTs. Another state, Idaho was identified to be lowest for SAT under lower income group.
#
#
# **Recommendations** In order to help bring up the overall likelihood of most students having better chances to enter college and essential prep and resources, we would like to recommend;
#
# - Allocating more funding / test preparation resources in states with lower income per capita such as Nevada, Mississippi, South Carolina and Idaho.
#
# - Recommend states to provide free waiver especially for lower income to access to OPL, Online prep live. Reports from OPL mentioned that one academic year associated with an average score of 1.64, especially boosting up students from the lower income group.([*source*](https://www.act.org/content/dam/act/unsecured/documents/R1705-test-prep-study-2018-08.pdf))
