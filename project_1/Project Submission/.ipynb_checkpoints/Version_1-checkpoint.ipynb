# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def convert_percent_commas(df):
    for col in df.columns:
        if 'family income' in col.lower():
            df[col] = df[col].replace('%','', regex=True).astype('int')
        elif 'number of students' in col.lower():
            df[col] = df[col].replace(',','', regex=True).astype('int')

# def is_integer_num(n):
#     if isinstance(n, int):
#         return True
#     if isinstance(n, float):
#         return n.is_integer()
#     return False


# def number_gen_get_first(string):
#     num_gen = []
#     notnumber = True
#     for i in string:
#         try:
#             if is_integer_num(int(i)) == True:
#                 num_gen.append(i)
#         except ValueError:
#             pass    
#     return int(''.join(num_gen))

def remove_punc_convertnum(alist):
    return ''.join([i for i in alist if i not in ['$',',']])
        

def Average(lst):
    return sum(lst) / len(lst)

def convert_percent_commas(alist):
    initlist = []
    for i in alist:
        if i == '$':
            initlist.append(i.replace('$','',regex = True))
        elif i == ',':
            initlist.append(i.replace(',','',regex = True))
        else:
            pass

def get_two_num_ave(string):
    count = 0
    first_num = 0
    second_num = 0 
    for num, word in enumerate (string.split()): 
        
        if word.isdigit() and count == 0:
            first_num = int(word)
            count += 1
        elif word.isdigit() and count != 0:
            second_num = int(word)
            count += 1
  
    if count == 0:
        return None
    
    else:
        return int((first_num+second_num)/count)

# %%
sat_college= pd.read_csv('sat_2019_by_intended_college_major.csv')

sat_college.sort_values(['TestTakers'],ascending=False)
# Out:
#                                  IntendedCollegeMajor TestTakers Percent  \
# 13         Foreign Languages and Literatures, General      9,936      1%
# 17  Liberal Arts and Sciences, General Studies and...      8,611      0%
# 6   Computer and Information Sciences and Support ...     79,736      4%
# 29                                Psychology, General     75,626      4%
# 8                                           Education     71,882      4%
# 30  Public Administration and Social Service Profe...      7,852      0%
# 21                              Military Technologies      7,448      0%
# 31                   Security and Protective Services     68,177      4%
# 25            Personal and Culinary Services, General      6,668      0%
# 20       Mechanic and Repair Technologies/Technicians      6,592      0%
# 12        Family and Consumer Sciences/Human Sciences      6,469      0%
# 5     Communication, Journalism, and Related Programs     36,332      2%
# 16                             Legal Studies, General     35,788      2%
# 14   Health Professions and related Clinical Sciences    331,026     18%
# 10               Engineering Technologies/Technicians     33,595      2%
# 32                                    Social Sciences     33,356      2%
# 28                               Precision Production        319      0%
# 26                   Philosophy and Religious Studies      3,381      0%
# 18                      Library Science/Librarianship        283      0%
# 1                   Architecture and Related Services     28,988      2%
# 36                                              Other     26,888      1%
# 27                                  Physical Sciences     26,318      1%
# 0   Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 4   Business, Management, Marketing, and Related S...    221,523     12%
# 22                    Multi/Interdisciplinary Studies      2,979      0%
# 2          Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 7                        Construction Trades, General      2,500      0%
# 9                                         Engineering    194,127     11%
# 19                         Mathematics and Statistics     16,508      1%
# 11            English Language and Literature/Letters     16,233      1%
# 3                  Biological and Biomedical Sciences    155,834      8%
# 35                Visual and Performing Arts, General    130,642      7%
# 24              Parks, Recreation and Leisure Studies     13,039      1%
# 37                                          Undecided    126,939      7%
# 15                                   History, General     12,611      1%
# 23                 Natural resources and Conservation     10,147      1%
# 33                   Theology and Religious Vocations      1,991      0%
# 34                Transportation and Materials Moving      1,105      0%
#
#     Total  ReadingWriting  Math
# 13   1102             566   536
# 17   1140             584   556
# 6    1156             571   585
# 29   1064             546   518
# 8    1022             519   503
# 30   1001             513   488
# 21    984             498   486
# 31    975             495   479
# 25    929             474   456
# 20    916             458   458
# 12    953             484   469
# 5    1069             550   519
# 16   1104             564   540
# 14   1048             529   518
# 10   1041             512   528
# 32   1164             594   570
# 28    932             466   466
# 26   1120             572   548
# 18   1105             577   527
# 1    1047             520   527
# 36    963             488   476
# 27   1203             597   606
# 0     977             496   481
# 4    1072             534   537
# 22   1155             581   574
# 2    1040             536   504
# 7     919             459   460
# 9    1139             559   581
# 19   1242             597   646
# 11   1119             585   533
# 3    1139             572   566
# 35   1045             536   510
# 24    960             482   478
# 37   1069             538   532
# 15   1090             563   527
# 23   1104             562   543
# 33   1096             561   535
# 34   1019             511   508

# %%
sat_college_act
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-c4b61ec8b0cc> in <module>
# ----> 1 sat_college_act
#
# NameError: name 'sat_college_act' is not defined

# %%
sat_college_act= pd.read_csv('sat_act_by_college.csv')

sat_college_act.groupby('Applies to Class Year(s)').mean()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d675f06e0129> in <module>
# ----> 1 sat_college_act= pd.read_csv('sat_act_by_college.csv')
#       2
#       3 sat_college_act.groupby('Applies to Class Year(s)').mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sat_act_by_college.csv'

# %%
sat_2019_ca= pd.read_csv('data\sat_2019_ca.csv')
sat_2019_ca.sort_values(['SName'],ascending=True).head(100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2051d240f55b> in <module>
# ----> 1 sat_2019_ca= pd.read_csv('data\sat_2019_ca.csv')
#       2 sat_2019_ca.sort_values(['SName'],ascending=True).head(100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\sat_2019_ca.csv'

# %%
sat_2019 = pd.read_csv('data\sat_2019.csv')

sat_2019 = pd.DataFrame(sat_2019)

sat_2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c0ee7e810f93> in <module>
# ----> 1 sat_2019 = pd.read_csv('data\sat_2019.csv')
#       2
#       3 sat_2019 = pd.DataFrame(sat_2019)
#       4
#       5 sat_2019
#
# NameError: name 'pd' is not defined

# %%
act_2019_ca = pd.read_csv('data\\act_2019_ca.csv')



act_2019_ca.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-adbd0befcc47> in <module>
# ----> 1 act_2019_ca = pd.read_csv('data\\act_2019_ca.csv')
#       2
#       3
#       4
#       5 act_2019_ca.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\act_2019_ca.csv'

# %%
v = act_2019_ca['Enroll12']
i1 = act_2019_ca['DName']
i2 = act_2019_ca['SName']
col = act_2019_ca['Enroll12']


act_2019_ca.pivot_table(values = v,index = i1, columns = i2,dropna=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-80072e60fb9c> in <module>
# ----> 1 v = act_2019_ca['Enroll12']
#       2 i1 = act_2019_ca['DName']
#       3 i2 = act_2019_ca['SName']
#       4 col = act_2019_ca['Enroll12']
#       5
#
# NameError: name 'act_2019_ca' is not defined

# %%
sat_2019['Percent Part'] = sat_2019['Participation Rate']

sat_2019['Percent Part'][39]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-3dc20bd80d5c> in <module>
# ----> 1 sat_2019['Percent Part'] = sat_2019['Participation Rate']
#       2
#       3 sat_2019['Percent Part'][39]
#
# NameError: name 'sat_2019' is not defined

# %%
sat_2019['Participation Rate']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9fa42fdf35e9> in <module>
# ----> 1 sat_2019['Participation Rate']
#
# NameError: name 'sat_2019' is not defined

# %%
# List comprehension
test = "—"
def remove_nonnumeric(word):
    return "".join(['' if letter in  ["%","—"]  else letter for letter in word])


remove_nonnumeric(test)
# Out:
# ''

# %%
sat_2019['Percent Part'] = sat_2019['Participation Rate'].apply(remove_nonnumeric)


sat_2019['Percent Part'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-68947d4f87cc> in <module>
# ----> 1 sat_2019['Percent Part'] = sat_2019['Participation Rate'].apply(remove_nonnumeric)
#       2
#       3
#       4 sat_2019['Percent Part'].astype(int)
#
# NameError: name 'sat_2019' is not defined

# %%
sns.pairplot(sat_2019)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-7a226f8c9da4> in <module>
# ----> 1 sns.pairplot(sat_2019)
#
# NameError: name 'sat_2019' is not defined

# %%
sns.histplot(sat_2019['Total'], bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-f5108e39e75b> in <module>
# ----> 1 sns.histplot(sat_2019['Total'], bins=50)
#
# NameError: name 'sat_2019' is not defined

# %%
satgpa= pd.read_csv('satgpa.csv')

# %%
satgpa.head()
# Out:
#    sex  sat_v  sat_m  sat_sum  hs_gpa  fy_gpa
# 0    1     65     62      127    3.40    3.18
# 1    2     58     64      122    4.00    3.33
# 2    2     56     60      116    3.75    3.25
# 3    1     42     53       95    3.75    2.42
# 4    1     55     52      107    4.00    2.63

# %%
satgpa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sex      1000 non-null   int64
#  1   sat_v    1000 non-null   int64
#  2   sat_m    1000 non-null   int64
#  3   sat_sum  1000 non-null   int64
#  4   hs_gpa   1000 non-null   float64
#  5   fy_gpa   1000 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 47.0 KB

# %%
# satgpa= pd.read_csv('data\satgpa.csv')


# y1 = satgpa['sat_sum']


# x1 = satgpa['hs_gpa']

# sns.lmplot(x = x1, y = y1, data = satgpa)

# %%
sns.regplot(x="hs_gpa", y="fy_gpa", data=satgpa);

# %%
sns.lmplot(x="hs_gpa", y="fy_gpa", data=satgpa, hue='sex');

# %%
sns.jointplot(x="hs_gpa", y="fy_gpa", data=satgpa, kind="reg")

# %%
x = 'hs_gpa'
y = 'sat_sum'
g = sns.jointplot(x="hs_gpa", y="sat_sum", data=satgpa, kind="hex", color = 'Blue' )
# sns.lmplot(x="hs_gpa", y="sat_sum",data=satgpa, 
#    ci=False, order=1)

sns.regplot(x, y, data =satgpa, marker=False, color = 'red')
regline.set_color('red')
regline.set_zorder(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-222822baf1c8> in <module>
#       6
#       7 sns.regplot(x, y, data =satgpa, marker=False, color = 'red')
# ----> 8 regline.set_color('red')
#       9 regline.set_zorder(5)
#
# NameError: name 'regline' is not defined

# %%
satgpa.corr()

# %%
# Create mask to prevent duplication of variables
mask = np.zeros(satgpa.corr().shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True

# %%
plt.figure(figsize=(16,12))
plt.title('Heatmap between GPA vs SATS', fontsize=14)
sns.heatmap(satgpa.corr(), cmap='RdBu', annot=True, mask=mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-67d6ba39a2df> in <module>
#       1 plt.figure(figsize=(16,12))
#       2 plt.title('Heatmap between GPA vs SATS', fontsize=14)
# ----> 3 sns.heatmap(satgpa.corr(), cmap='RdBu', annot=True, mask=mask)
#
# NameError: name 'mask' is not defined

# %%
income_ca= pd.read_csv('Data/Income taking SATS in California.csv')

# %%
income_ca
# Out:
#                 Family Income NumTestakers   Pct  Critical Reading Mean  \
# 0           Less than $20,000      124,290  13.0                    435
# 1    About $20,000 to $40,000      158,909  16.0                    465
# 2    About $40,001 to $60,000      132,182  14.0                    488
# 3    About $60,001 to $80,000      115,998  12.0                    503
# 4   About $80,001 to $100,000      119,593  12.0                    517
# 5  About $100,001 to $140,000      146,434  15.0                    530
# 6  About $140,001 to $200,000       93,275  10.0                    542
# 7          More than $200,000       87,482   9.0                    569
# 8                 No Response      659,426   NaN                    482
#
#    Critical Reading SD  Math Mean  Math SD  Writing Mean  Writing SD
# 0                  104        453      115           426         101
# 1                  102        477      109           452          99
# 2                  101        495      107           471          99
# 3                  101        509      105           485          99
# 4                  100        527      106           501         100
# 5                  101        539      105           513         101
# 6                  102        553      106           528         103
# 7                  105        586      107           562         108
# 8                  126        501      131           473         125

# %%
income_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Family Income          9 non-null      object
#  1   NumTestakers           9 non-null      object
#  2   Pct                    8 non-null      float64
#  3   Critical Reading Mean  9 non-null      int64
#  4   Critical Reading SD    9 non-null      int64
#  5   Math Mean              9 non-null      int64
#  6   Math SD                9 non-null      int64
#  7   Writing Mean           9 non-null      int64
#  8   Writing SD             9 non-null      int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 776.0+ bytes

# %%
#remove punctuation s from Column 1 

income_ca['Family Income'] = income_ca['Family Income'].apply(remove_punc_convertnum)
income_ca['NumTestakers'] = income_ca['NumTestakers'].apply(remove_punc_convertnum)
#get average of two numbers in a string and convert to float
income_ca['Family Income'] = income_ca['Family Income'].apply(get_two_num_ave)
income_ca['NumTestakers'] = income_ca['NumTestakers'].apply(int)

# %%
#check if object changed to float 

income_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Family Income          8 non-null      float64
#  1   NumTestakers           9 non-null      int64
#  2   Pct                    8 non-null      float64
#  3   Critical Reading Mean  9 non-null      int64
#  4   Critical Reading SD    9 non-null      int64
#  5   Math Mean              9 non-null      int64
#  6   Math SD                9 non-null      int64
#  7   Writing Mean           9 non-null      int64
#  8   Writing SD             9 non-null      int64
# dtypes: float64(2), int64(7)
# memory usage: 776.0 bytes

# %%
g = sns.lmplot(x="Family Income", y="Math Mean", data=income_ca, aspect = 2)

# %%
sns.pairplot(income_ca, x_vars=["Math Mean","Writing Mean", "Critical Reading Mean","NumTestakers"], y_vars=["Family Income",],
             height=5, aspect=1, kind="reg");

# %%
sample = 'More than 200000'

def get_two_num_ave(string):
    count = 0
    first_num = 0
    second_num = 0 
    for num, word in enumerate (string.split()): 
        
        if word.isdigit() and count == 0:
            first_num = int(word)
            count += 1
        elif word.isdigit() and count != 0:
            second_num = int(word)
            count += 1
  
    if count == 0:
        return None
    
    else:
        return int((first_num+second_num)/count)

get_two_num_ave(sample)
# Out:
# 200000

# %%
def convert_percent_commas(df):
    for col in df.columns:
        if 'family income' in col.lower():
            df[col] = df[col].replace('%','', regex=True).astype('int')
        elif 'number of students' in col.lower():
            df[col] = df[col].replace(',','', regex=True).astype('int')

def is_integer_num(n):
    if isinstance(n, int):
        return True
    if isinstance(n, float):
        return n.is_integer()
    return False


def number_gen_get_first(string):
    num_gen = []
    notnumber = True
    for i in string:
        try:
            if is_integer_num(int(i)) == True:
                num_gen.append(i)
        except ValueError:
            pass    
    return int(''.join(num_gen))

def remove_punc_convertnum(alist):
    return ''.join([i for i in alist if i not in ['$',',']])
        

def Average(lst):
    return sum(lst) / len(lst)

def convert_percent_commas(alist):
    initlist = []
    for i in alist:
        if i == '$':
            initlist.append(i.replace('$','',regex = True))
        elif i == ',':
            initlist.append(i.replace(',','',regex = True))
        else:
            pass

# %%
def change_title(df,before,after):
    putlist = [x for x in df.columns]
    output = []
    for string in putlist:
        output.append(string.replace(before,after))  
    df.columns = output
    return df

# %% [markdown]
# # Analyse California by Major

# %%
a = pd.DataFrame(
    { }
)
