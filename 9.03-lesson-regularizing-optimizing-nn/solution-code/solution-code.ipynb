# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Regularization for Neural Networks
#
# ### Learning Objectives
#
# By the end of the lesson, students should be able to:
# 1. Explain how the three deep learning regularization techniques work
#     * L1/L2 regularization
#     * Dropout
#     * Early stopping
# 2. Implement these techniques in Keras

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('../data/cell_phone_churn.csv')
data.head()
# Out:
#   state  account_length  area_code intl_plan vmail_plan  vmail_message  \
# 0    KS             128        415        no        yes             25
# 1    OH             107        415        no        yes             26
# 2    NJ             137        415        no         no              0
# 3    OH              84        408       yes         no              0
# 4    OK              75        415       yes         no              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    custserv_calls  churn
# 0               1  False
# 1               1  False
# 2               0  False
# 3               2  False
# 4               3  False

# %%
# Drop state column
# data = data.drop('state', axis=1)
# data = data.drop('area_code', axis=1)
# data.drop(columns = ['state', 'area_code'], inplace = True)

# One-hot encode state & area columns
data = pd.get_dummies(data, columns = ['state', 'area_code'], drop_first = True)

# Binarize intil_plan and vmail_plan columns
# Many ways to binarize:
data['intl_plan'] = data['intl_plan'].map(lambda x: 1 if x=='yes' else 0)
data['vmail_plan'] = data['vmail_plan'].map(lambda x: 1 if x=='yes' else 0)

# data['intl_plan'] = data['intl_plan'].map({'yes': 1, 'no': 0})
# data['intl_plan'] = (data['intl_plan'] == 'yes').astype('int')
# data['intl_plan'] = (data['intl_plan'] == 'yes') * 1
# data['intl_plan'] = np.where(data['intl_plan'] == 'yes', 1, 0)

# %%
# Split into X and y
X = data.drop('churn', axis=1)
y = data['churn'].astype('int')

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# Scale data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
1 - y.mean()
# Out:
# 0.8550855085508551

# %% [markdown]
# ## Build a simple neural net to model churn
#
# Let's build this:
#
# - a dense network,
# - one input layer,
# - one hidden layer
#   - slightly smaller than input layer
#   - ReLU activation
# - single node output (for binary classification)

# %% [markdown]
# <details><summary>What activation function will we use for our output layer here?</summary>
#
# - Sigmoid activation, since we are doing binary classification.
# </details>

# %% [markdown]
# > **Fun fact**: If we dropped the hidden layer, this model would just be logistic regression!  Can you prove that to yourself?

# %%
X.shape
# Out:
# (3333, 69)

# %%
y.shape
# Out:
# (3333,)

# %%
# binary classification 

model = Sequential()

# input layer 
model.add(Dense(69, input_shape = (69,), activation= 'relu'))
model.add(Dense(20, activation= 'relu'))

model.add(Dense(1,activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc']) # loss = 'bce'

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    verbose=2
)
# Out:
# Epoch 1/100
# 79/79 - 1s - loss: 0.4331 - acc: 0.8387 - val_loss: 0.3702 - val_acc: 0.8561 - 610ms/epoch - 8ms/step
# Epoch 2/100
# 79/79 - 0s - loss: 0.3432 - acc: 0.8563 - val_loss: 0.3382 - val_acc: 0.8645 - 109ms/epoch - 1ms/step
# Epoch 3/100
# 79/79 - 0s - loss: 0.3069 - acc: 0.8659 - val_loss: 0.3212 - val_acc: 0.8681 - 109ms/epoch - 1ms/step
# Epoch 4/100
# 79/79 - 0s - loss: 0.2812 - acc: 0.8824 - val_loss: 0.3089 - val_acc: 0.8693 - 108ms/epoch - 1ms/step
# Epoch 5/100
# 79/79 - 0s - loss: 0.2593 - acc: 0.8936 - val_loss: 0.2997 - val_acc: 0.8849 - 111ms/epoch - 1ms/step
# Epoch 6/100
# 79/79 - 0s - loss: 0.2355 - acc: 0.9060 - val_loss: 0.2875 - val_acc: 0.8873 - 108ms/epoch - 1ms/step
# Epoch 7/100
# 79/79 - 0s - loss: 0.2146 - acc: 0.9212 - val_loss: 0.2829 - val_acc: 0.8993 - 98ms/epoch - 1ms/step
# Epoch 8/100
# 79/79 - 0s - loss: 0.1966 - acc: 0.9300 - val_loss: 0.2796 - val_acc: 0.8969 - 97ms/epoch - 1ms/step
# Epoch 9/100
# 79/79 - 0s - loss: 0.1803 - acc: 0.9404 - val_loss: 0.2768 - val_acc: 0.9029 - 96ms/epoch - 1ms/step
# Epoch 10/100
# 79/79 - 0s - loss: 0.1699 - acc: 0.9448 - val_loss: 0.2770 - val_acc: 0.9041 - 98ms/epoch - 1ms/step
# Epoch 11/100
# 79/79 - 0s - loss: 0.1569 - acc: 0.9492 - val_loss: 0.2805 - val_acc: 0.8981 - 97ms/epoch - 1ms/step
# Epoch 12/100
# 79/79 - 0s - loss: 0.1454 - acc: 0.9532 - val_loss: 0.2910 - val_acc: 0.8969 - 100ms/epoch - 1ms/step
# Epoch 13/100
# 79/79 - 0s - loss: 0.1358 - acc: 0.9536 - val_loss: 0.2864 - val_acc: 0.8909 - 96ms/epoch - 1ms/step
# Epoch 14/100
# 79/79 - 0s - loss: 0.1255 - acc: 0.9592 - val_loss: 0.2940 - val_acc: 0.9029 - 93ms/epoch - 1ms/step
# Epoch 15/100
# 79/79 - 0s - loss: 0.1158 - acc: 0.9624 - val_loss: 0.2993 - val_acc: 0.9029 - 108ms/epoch - 1ms/step
# Epoch 16/100
# 79/79 - 0s - loss: 0.1155 - acc: 0.9616 - val_loss: 0.3023 - val_acc: 0.8969 - 95ms/epoch - 1ms/step
# Epoch 17/100
# 79/79 - 0s - loss: 0.1009 - acc: 0.9740 - val_loss: 0.3112 - val_acc: 0.8921 - 95ms/epoch - 1ms/step
# Epoch 18/100
# 79/79 - 0s - loss: 0.0941 - acc: 0.9708 - val_loss: 0.3127 - val_acc: 0.8945 - 93ms/epoch - 1ms/step
# Epoch 19/100
# 79/79 - 0s - loss: 0.0846 - acc: 0.9736 - val_loss: 0.3182 - val_acc: 0.9029 - 154ms/epoch - 2ms/step
# Epoch 20/100
# 79/79 - 0s - loss: 0.0784 - acc: 0.9772 - val_loss: 0.3299 - val_acc: 0.8993 - 120ms/epoch - 2ms/step
# Epoch 21/100
# 79/79 - 0s - loss: 0.0746 - acc: 0.9784 - val_loss: 0.3298 - val_acc: 0.8945 - 99ms/epoch - 1ms/step
# Epoch 22/100
# 79/79 - 0s - loss: 0.0656 - acc: 0.9820 - val_loss: 0.3417 - val_acc: 0.8969 - 93ms/epoch - 1ms/step
# Epoch 23/100
# 79/79 - 0s - loss: 0.0618 - acc: 0.9836 - val_loss: 0.3462 - val_acc: 0.8957 - 91ms/epoch - 1ms/step
# Epoch 24/100
# 79/79 - 0s - loss: 0.0548 - acc: 0.9876 - val_loss: 0.3497 - val_acc: 0.9017 - 92ms/epoch - 1ms/step
# Epoch 25/100
# 79/79 - 0s - loss: 0.0517 - acc: 0.9876 - val_loss: 0.3628 - val_acc: 0.8957 - 95ms/epoch - 1ms/step
# Epoch 26/100
# 79/79 - 0s - loss: 0.0485 - acc: 0.9888 - val_loss: 0.3773 - val_acc: 0.8933 - 100ms/epoch - 1ms/step
# Epoch 27/100
# 79/79 - 0s - loss: 0.0433 - acc: 0.9880 - val_loss: 0.3908 - val_acc: 0.8897 - 93ms/epoch - 1ms/step
# Epoch 28/100
# 79/79 - 0s - loss: 0.0388 - acc: 0.9932 - val_loss: 0.4029 - val_acc: 0.8921 - 101ms/epoch - 1ms/step
# Epoch 29/100
# 79/79 - 0s - loss: 0.0360 - acc: 0.9948 - val_loss: 0.3976 - val_acc: 0.8945 - 106ms/epoch - 1ms/step
# Epoch 30/100
# 79/79 - 0s - loss: 0.0325 - acc: 0.9948 - val_loss: 0.4154 - val_acc: 0.8933 - 101ms/epoch - 1ms/step
# Epoch 31/100
# 79/79 - 0s - loss: 0.0345 - acc: 0.9908 - val_loss: 0.4429 - val_acc: 0.8885 - 98ms/epoch - 1ms/step
# Epoch 32/100
# 79/79 - 0s - loss: 0.0334 - acc: 0.9920 - val_loss: 0.4366 - val_acc: 0.8921 - 97ms/epoch - 1ms/step
# Epoch 33/100
# 79/79 - 0s - loss: 0.0252 - acc: 0.9952 - val_loss: 0.4316 - val_acc: 0.8873 - 90ms/epoch - 1ms/step
# Epoch 34/100
# 79/79 - 0s - loss: 0.0231 - acc: 0.9960 - val_loss: 0.4503 - val_acc: 0.8909 - 96ms/epoch - 1ms/step
# Epoch 35/100
# 79/79 - 0s - loss: 0.0199 - acc: 0.9964 - val_loss: 0.4587 - val_acc: 0.8873 - 104ms/epoch - 1ms/step
# Epoch 36/100
# 79/79 - 0s - loss: 0.0190 - acc: 0.9972 - val_loss: 0.4658 - val_acc: 0.8957 - 103ms/epoch - 1ms/step
# Epoch 37/100
# 79/79 - 0s - loss: 0.0181 - acc: 0.9976 - val_loss: 0.4793 - val_acc: 0.8849 - 101ms/epoch - 1ms/step
# Epoch 38/100
# 79/79 - 0s - loss: 0.0149 - acc: 0.9984 - val_loss: 0.4809 - val_acc: 0.8909 - 87ms/epoch - 1ms/step
# Epoch 39/100
# 79/79 - 0s - loss: 0.0138 - acc: 0.9984 - val_loss: 0.4909 - val_acc: 0.8897 - 93ms/epoch - 1ms/step
# Epoch 40/100
# 79/79 - 0s - loss: 0.0140 - acc: 0.9988 - val_loss: 0.4964 - val_acc: 0.8957 - 101ms/epoch - 1ms/step
# Epoch 41/100
# 79/79 - 0s - loss: 0.0122 - acc: 0.9992 - val_loss: 0.5138 - val_acc: 0.8945 - 105ms/epoch - 1ms/step
# Epoch 42/100
# 79/79 - 0s - loss: 0.0111 - acc: 0.9984 - val_loss: 0.5164 - val_acc: 0.8885 - 114ms/epoch - 1ms/step
# Epoch 43/100
# 79/79 - 0s - loss: 0.0097 - acc: 0.9988 - val_loss: 0.5282 - val_acc: 0.8957 - 101ms/epoch - 1ms/step
# Epoch 44/100
# 79/79 - 0s - loss: 0.0091 - acc: 0.9988 - val_loss: 0.5390 - val_acc: 0.8873 - 93ms/epoch - 1ms/step
# Epoch 45/100
# 79/79 - 0s - loss: 0.0078 - acc: 1.0000 - val_loss: 0.5462 - val_acc: 0.8957 - 91ms/epoch - 1ms/step
# Epoch 46/100
# 79/79 - 0s - loss: 0.0073 - acc: 0.9996 - val_loss: 0.5596 - val_acc: 0.8909 - 93ms/epoch - 1ms/step
# Epoch 47/100
# 79/79 - 0s - loss: 0.0069 - acc: 1.0000 - val_loss: 0.5633 - val_acc: 0.8885 - 94ms/epoch - 1ms/step
# Epoch 48/100
# 79/79 - 0s - loss: 0.0063 - acc: 0.9996 - val_loss: 0.5733 - val_acc: 0.8897 - 111ms/epoch - 1ms/step
# Epoch 49/100
# 79/79 - 0s - loss: 0.0056 - acc: 0.9996 - val_loss: 0.5731 - val_acc: 0.8873 - 108ms/epoch - 1ms/step
# Epoch 50/100
# 79/79 - 0s - loss: 0.0053 - acc: 0.9996 - val_loss: 0.5880 - val_acc: 0.8885 - 98ms/epoch - 1ms/step
# Epoch 51/100
# 79/79 - 0s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.6000 - val_acc: 0.8897 - 86ms/epoch - 1ms/step
# Epoch 52/100
# 79/79 - 0s - loss: 0.0049 - acc: 1.0000 - val_loss: 0.6095 - val_acc: 0.8909 - 92ms/epoch - 1ms/step
# Epoch 53/100
# 79/79 - 0s - loss: 0.0042 - acc: 1.0000 - val_loss: 0.6031 - val_acc: 0.8825 - 93ms/epoch - 1ms/step
# Epoch 54/100
# 79/79 - 0s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.6245 - val_acc: 0.8909 - 94ms/epoch - 1ms/step
# Epoch 55/100
# 79/79 - 0s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.6234 - val_acc: 0.8873 - 95ms/epoch - 1ms/step
# Epoch 56/100
# 79/79 - 0s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.6376 - val_acc: 0.8885 - 89ms/epoch - 1ms/step
# Epoch 57/100
# 79/79 - 0s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.6467 - val_acc: 0.8885 - 94ms/epoch - 1ms/step
# Epoch 58/100
# 79/79 - 0s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.6594 - val_acc: 0.8861 - 91ms/epoch - 1ms/step
# Epoch 59/100
# 79/79 - 0s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.6535 - val_acc: 0.8873 - 94ms/epoch - 1ms/step
# Epoch 60/100
# 79/79 - 0s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.6537 - val_acc: 0.8873 - 90ms/epoch - 1ms/step
# Epoch 61/100
# 79/79 - 0s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.6718 - val_acc: 0.8861 - 90ms/epoch - 1ms/step
# Epoch 62/100
# 79/79 - 0s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.6795 - val_acc: 0.8861 - 92ms/epoch - 1ms/step
# Epoch 63/100
# 79/79 - 0s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.6862 - val_acc: 0.8873 - 117ms/epoch - 1ms/step
# Epoch 64/100
# 79/79 - 0s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.6953 - val_acc: 0.8861 - 126ms/epoch - 2ms/step
# Epoch 65/100
# 79/79 - 0s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.7059 - val_acc: 0.8933 - 113ms/epoch - 1ms/step
# Epoch 66/100
# 79/79 - 0s - loss: 0.0046 - acc: 0.9992 - val_loss: 0.7144 - val_acc: 0.8837 - 101ms/epoch - 1ms/step
# Epoch 67/100
# 79/79 - 0s - loss: 0.0156 - acc: 0.9948 - val_loss: 0.7668 - val_acc: 0.8705 - 91ms/epoch - 1ms/step
# Epoch 68/100
# 79/79 - 0s - loss: 0.0165 - acc: 0.9944 - val_loss: 0.7142 - val_acc: 0.8777 - 91ms/epoch - 1ms/step
# Epoch 69/100
# 79/79 - 0s - loss: 0.0189 - acc: 0.9956 - val_loss: 0.7262 - val_acc: 0.8861 - 101ms/epoch - 1ms/step
# Epoch 70/100
# 79/79 - 0s - loss: 0.0043 - acc: 0.9992 - val_loss: 0.6899 - val_acc: 0.8921 - 102ms/epoch - 1ms/step
# Epoch 71/100
# 79/79 - 0s - loss: 0.0025 - acc: 0.9996 - val_loss: 0.7205 - val_acc: 0.8885 - 100ms/epoch - 1ms/step
# Epoch 72/100
# 79/79 - 0s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.7294 - val_acc: 0.8909 - 103ms/epoch - 1ms/step
# Epoch 73/100
# 79/79 - 0s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.7418 - val_acc: 0.8921 - 97ms/epoch - 1ms/step
# Epoch 74/100
# 79/79 - 0s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.7413 - val_acc: 0.8933 - 97ms/epoch - 1ms/step
# Epoch 75/100
# 79/79 - 0s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.7464 - val_acc: 0.8933 - 91ms/epoch - 1ms/step
# Epoch 76/100
# 79/79 - 0s - loss: 9.6359e-04 - acc: 1.0000 - val_loss: 0.7514 - val_acc: 0.8933 - 106ms/epoch - 1ms/step
# Epoch 77/100
# 79/79 - 0s - loss: 8.9705e-04 - acc: 1.0000 - val_loss: 0.7552 - val_acc: 0.8945 - 111ms/epoch - 1ms/step
# Epoch 78/100
# 79/79 - 0s - loss: 8.4661e-04 - acc: 1.0000 - val_loss: 0.7649 - val_acc: 0.8921 - 98ms/epoch - 1ms/step
# Epoch 79/100
# 79/79 - 0s - loss: 7.8069e-04 - acc: 1.0000 - val_loss: 0.7689 - val_acc: 0.8933 - 90ms/epoch - 1ms/step
# Epoch 80/100
# 79/79 - 0s - loss: 7.4485e-04 - acc: 1.0000 - val_loss: 0.7718 - val_acc: 0.8933 - 89ms/epoch - 1ms/step
# Epoch 81/100
# 79/79 - 0s - loss: 7.0552e-04 - acc: 1.0000 - val_loss: 0.7787 - val_acc: 0.8921 - 91ms/epoch - 1ms/step
# Epoch 82/100
# 79/79 - 0s - loss: 6.5863e-04 - acc: 1.0000 - val_loss: 0.7833 - val_acc: 0.8897 - 90ms/epoch - 1ms/step
# Epoch 83/100
# 79/79 - 0s - loss: 6.3428e-04 - acc: 1.0000 - val_loss: 0.7878 - val_acc: 0.8909 - 89ms/epoch - 1ms/step
# Epoch 84/100
# 79/79 - 0s - loss: 5.9610e-04 - acc: 1.0000 - val_loss: 0.7955 - val_acc: 0.8921 - 92ms/epoch - 1ms/step
# Epoch 85/100
# 79/79 - 0s - loss: 5.6587e-04 - acc: 1.0000 - val_loss: 0.8024 - val_acc: 0.8897 - 92ms/epoch - 1ms/step
# Epoch 86/100
# 79/79 - 0s - loss: 5.4613e-04 - acc: 1.0000 - val_loss: 0.8037 - val_acc: 0.8873 - 90ms/epoch - 1ms/step
# Epoch 87/100
# 79/79 - 0s - loss: 5.2264e-04 - acc: 1.0000 - val_loss: 0.8111 - val_acc: 0.8909 - 96ms/epoch - 1ms/step
# Epoch 88/100
# 79/79 - 0s - loss: 4.8821e-04 - acc: 1.0000 - val_loss: 0.8127 - val_acc: 0.8921 - 104ms/epoch - 1ms/step
# Epoch 89/100
# 79/79 - 0s - loss: 4.6689e-04 - acc: 1.0000 - val_loss: 0.8168 - val_acc: 0.8885 - 95ms/epoch - 1ms/step
# Epoch 90/100
# 79/79 - 0s - loss: 4.5424e-04 - acc: 1.0000 - val_loss: 0.8185 - val_acc: 0.8909 - 95ms/epoch - 1ms/step
# Epoch 91/100
# 79/79 - 0s - loss: 4.2390e-04 - acc: 1.0000 - val_loss: 0.8247 - val_acc: 0.8897 - 90ms/epoch - 1ms/step
# Epoch 92/100
# 79/79 - 0s - loss: 3.9927e-04 - acc: 1.0000 - val_loss: 0.8333 - val_acc: 0.8909 - 92ms/epoch - 1ms/step
# Epoch 93/100
# 79/79 - 0s - loss: 3.8383e-04 - acc: 1.0000 - val_loss: 0.8330 - val_acc: 0.8897 - 95ms/epoch - 1ms/step
# Epoch 94/100
# 79/79 - 0s - loss: 4.2233e-04 - acc: 1.0000 - val_loss: 0.8424 - val_acc: 0.8909 - 89ms/epoch - 1ms/step
# Epoch 95/100
# 79/79 - 0s - loss: 3.5576e-04 - acc: 1.0000 - val_loss: 0.8446 - val_acc: 0.8897 - 89ms/epoch - 1ms/step
# Epoch 96/100
# 79/79 - 0s - loss: 3.3683e-04 - acc: 1.0000 - val_loss: 0.8510 - val_acc: 0.8909 - 91ms/epoch - 1ms/step
# Epoch 97/100
# 79/79 - 0s - loss: 3.1870e-04 - acc: 1.0000 - val_loss: 0.8551 - val_acc: 0.8885 - 98ms/epoch - 1ms/step
# Epoch 98/100
# 79/79 - 0s - loss: 3.0390e-04 - acc: 1.0000 - val_loss: 0.8649 - val_acc: 0.8885 - 92ms/epoch - 1ms/step
# Epoch 99/100
# 79/79 - 0s - loss: 2.9588e-04 - acc: 1.0000 - val_loss: 0.8618 - val_acc: 0.8885 - 103ms/epoch - 1ms/step
# Epoch 100/100
# 79/79 - 0s - loss: 3.4282e-04 - acc: 1.0000 - val_loss: 0.8725 - val_acc: 0.8849 - 90ms/epoch - 1ms/step

# %%
train_loss = history.history['acc']
test_loss = history.history['val_acc']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %%
history.history['acc'][-1], history.history['val_acc'][-1]
# Out:
# (1.0, 0.8848921060562134)

# %%
model.summary()

# input layer 69 * 20
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 69)                4830
#
#  dense_81 (Dense)            (None, 20)                1400
#
#  dense_82 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 6,251
# Trainable params: 6,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![](../assets/overkill.jpg)

# %% [markdown]
# <a id='l1'></a>
# ## Regularization Method 1: $\mathcal{l}_1$ and $\mathcal{l}_2$
# ---
# Just as we did with linear models, we can use $\mathcal{l}_1$ (LASSO) and $\mathcal{l}_2$ (Ridge) regularization on our neural networks.
#
# Recall from our notation:
#
# * $J(\theta) = L(\mathbf{y}, \hat{\mathbf{y}})$ is the value of the loss function with respect to...
# * $\theta$, the list of _all_ model coefficients (all weights and biases).
#
# We regularize our neural networks by adding a penalty term to our loss function:
#
# $$ \text{minimize } J(\theta) + \lambda \|\theta\|_2^2 $$
#
# This has the effect of penalizing our parameters $\theta$ by shrinking them, hence bartering in the bias-variance tradeoff by (hopefully) reducing variance by adding bias. Although it is rarely done, **Keras actually gives us the opportunity to penalize the weights at different layers by different amounts.**
#
# ## Which to pick: $\mathcal{l}_1$ or $\mathcal{l}_2$?
# Recall the key difference: $\mathcal{l}_1$ penalties perform _selection_. That is, they often zero out parameters when they're small enough. While this sounds appealing, $\mathcal{l}_2$ is used almost exclusively. It's done so often, that deep learning practitions give it a special name: **weight decay**.

# %%
# differentiation much smoother on l2 
# gradient descent will be smooth.

# %%
# from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l1

model_l1 = Sequential()

n_input = X_train.shape[1]

model_l1.add(Dense(
    69,
    input_dim=n_input,
    activation='relu',
    kernel_regularizer=l1(0.001) # put in regulizers 
))

model_l1.add(Dense(
    20,
    activation='relu',
    kernel_regularizer=l1(0.001)
))

model_l1.add(Dense(
    1,
    activation='sigmoid',
    kernel_regularizer=l1(0.001)
))

model_l1.compile(
    loss='bce',
    optimizer='adam',
    metrics=['acc']
)

history_l1 = model_l1.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    verbose = 2
)
# Out:
# Epoch 1/100
# 79/79 - 1s - loss: 1.0801 - acc: 0.8375 - val_loss: 0.9721 - val_acc: 0.8525 - 579ms/epoch - 7ms/step
# Epoch 2/100
# 79/79 - 0s - loss: 0.8980 - acc: 0.8587 - val_loss: 0.8463 - val_acc: 0.8693 - 103ms/epoch - 1ms/step
# Epoch 3/100
# 79/79 - 0s - loss: 0.7764 - acc: 0.8735 - val_loss: 0.7571 - val_acc: 0.8777 - 111ms/epoch - 1ms/step
# Epoch 4/100
# 79/79 - 0s - loss: 0.6869 - acc: 0.8948 - val_loss: 0.6881 - val_acc: 0.8765 - 110ms/epoch - 1ms/step
# Epoch 5/100
# 79/79 - 0s - loss: 0.6178 - acc: 0.9032 - val_loss: 0.6360 - val_acc: 0.8945 - 104ms/epoch - 1ms/step
# Epoch 6/100
# 79/79 - 0s - loss: 0.5641 - acc: 0.9144 - val_loss: 0.5930 - val_acc: 0.8933 - 97ms/epoch - 1ms/step
# Epoch 7/100
# 79/79 - 0s - loss: 0.5212 - acc: 0.9232 - val_loss: 0.5645 - val_acc: 0.9041 - 101ms/epoch - 1ms/step
# Epoch 8/100
# 79/79 - 0s - loss: 0.4914 - acc: 0.9284 - val_loss: 0.5392 - val_acc: 0.8969 - 103ms/epoch - 1ms/step
# Epoch 9/100
# 79/79 - 0s - loss: 0.4619 - acc: 0.9312 - val_loss: 0.5212 - val_acc: 0.9017 - 98ms/epoch - 1ms/step
# Epoch 10/100
# 79/79 - 0s - loss: 0.4406 - acc: 0.9344 - val_loss: 0.5014 - val_acc: 0.9053 - 96ms/epoch - 1ms/step
# Epoch 11/100
# 79/79 - 0s - loss: 0.4204 - acc: 0.9388 - val_loss: 0.4847 - val_acc: 0.9005 - 95ms/epoch - 1ms/step
# Epoch 12/100
# 79/79 - 0s - loss: 0.4031 - acc: 0.9376 - val_loss: 0.4730 - val_acc: 0.9053 - 114ms/epoch - 1ms/step
# Epoch 13/100
# 79/79 - 0s - loss: 0.3866 - acc: 0.9396 - val_loss: 0.4694 - val_acc: 0.9017 - 117ms/epoch - 1ms/step
# Epoch 14/100
# 79/79 - 0s - loss: 0.3777 - acc: 0.9412 - val_loss: 0.4510 - val_acc: 0.9029 - 120ms/epoch - 2ms/step
# Epoch 15/100
# 79/79 - 0s - loss: 0.3624 - acc: 0.9440 - val_loss: 0.4423 - val_acc: 0.9041 - 114ms/epoch - 1ms/step
# Epoch 16/100
# 79/79 - 0s - loss: 0.3508 - acc: 0.9444 - val_loss: 0.4383 - val_acc: 0.9029 - 116ms/epoch - 1ms/step
# Epoch 17/100
# 79/79 - 0s - loss: 0.3417 - acc: 0.9468 - val_loss: 0.4300 - val_acc: 0.9017 - 115ms/epoch - 1ms/step
# Epoch 18/100
# 79/79 - 0s - loss: 0.3312 - acc: 0.9508 - val_loss: 0.4283 - val_acc: 0.9089 - 106ms/epoch - 1ms/step
# Epoch 19/100
# 79/79 - 0s - loss: 0.3262 - acc: 0.9492 - val_loss: 0.4206 - val_acc: 0.9065 - 109ms/epoch - 1ms/step
# Epoch 20/100
# 79/79 - 0s - loss: 0.3184 - acc: 0.9480 - val_loss: 0.4187 - val_acc: 0.9077 - 110ms/epoch - 1ms/step
# Epoch 21/100
# 79/79 - 0s - loss: 0.3100 - acc: 0.9496 - val_loss: 0.4156 - val_acc: 0.9017 - 105ms/epoch - 1ms/step
# Epoch 22/100
# 79/79 - 0s - loss: 0.3035 - acc: 0.9540 - val_loss: 0.4102 - val_acc: 0.9041 - 91ms/epoch - 1ms/step
# Epoch 23/100
# 79/79 - 0s - loss: 0.2983 - acc: 0.9516 - val_loss: 0.4045 - val_acc: 0.9101 - 98ms/epoch - 1ms/step
# Epoch 24/100
# 79/79 - 0s - loss: 0.2934 - acc: 0.9584 - val_loss: 0.4055 - val_acc: 0.9089 - 115ms/epoch - 1ms/step
# Epoch 25/100
# 79/79 - 0s - loss: 0.2876 - acc: 0.9560 - val_loss: 0.4047 - val_acc: 0.9041 - 115ms/epoch - 1ms/step
# Epoch 26/100
# 79/79 - 0s - loss: 0.2937 - acc: 0.9476 - val_loss: 0.4018 - val_acc: 0.9029 - 106ms/epoch - 1ms/step
# Epoch 27/100
# 79/79 - 0s - loss: 0.2799 - acc: 0.9556 - val_loss: 0.4048 - val_acc: 0.9029 - 91ms/epoch - 1ms/step
# Epoch 28/100
# 79/79 - 0s - loss: 0.2768 - acc: 0.9572 - val_loss: 0.4042 - val_acc: 0.9005 - 111ms/epoch - 1ms/step
# Epoch 29/100
# 79/79 - 0s - loss: 0.2771 - acc: 0.9556 - val_loss: 0.4030 - val_acc: 0.9101 - 109ms/epoch - 1ms/step
# Epoch 30/100
# 79/79 - 0s - loss: 0.2669 - acc: 0.9608 - val_loss: 0.4033 - val_acc: 0.9065 - 117ms/epoch - 1ms/step
# Epoch 31/100
# 79/79 - 0s - loss: 0.2707 - acc: 0.9584 - val_loss: 0.4016 - val_acc: 0.9065 - 93ms/epoch - 1ms/step
# Epoch 32/100
# 79/79 - 0s - loss: 0.2625 - acc: 0.9600 - val_loss: 0.3993 - val_acc: 0.9053 - 109ms/epoch - 1ms/step
# Epoch 33/100
# 79/79 - 0s - loss: 0.2572 - acc: 0.9632 - val_loss: 0.4053 - val_acc: 0.9029 - 109ms/epoch - 1ms/step
# Epoch 34/100
# 79/79 - 0s - loss: 0.2551 - acc: 0.9632 - val_loss: 0.4040 - val_acc: 0.9053 - 111ms/epoch - 1ms/step
# Epoch 35/100
# 79/79 - 0s - loss: 0.2508 - acc: 0.9652 - val_loss: 0.4040 - val_acc: 0.9077 - 97ms/epoch - 1ms/step
# Epoch 36/100
# 79/79 - 0s - loss: 0.2487 - acc: 0.9640 - val_loss: 0.4025 - val_acc: 0.9113 - 115ms/epoch - 1ms/step
# Epoch 37/100
# 79/79 - 0s - loss: 0.2472 - acc: 0.9632 - val_loss: 0.4081 - val_acc: 0.9065 - 94ms/epoch - 1ms/step
# Epoch 38/100
# 79/79 - 0s - loss: 0.2441 - acc: 0.9652 - val_loss: 0.4033 - val_acc: 0.8969 - 92ms/epoch - 1ms/step
# Epoch 39/100
# 79/79 - 0s - loss: 0.2475 - acc: 0.9648 - val_loss: 0.4075 - val_acc: 0.9077 - 91ms/epoch - 1ms/step
# Epoch 40/100
# 79/79 - 0s - loss: 0.2387 - acc: 0.9708 - val_loss: 0.4081 - val_acc: 0.9041 - 109ms/epoch - 1ms/step
# Epoch 41/100
# 79/79 - 0s - loss: 0.2367 - acc: 0.9676 - val_loss: 0.4123 - val_acc: 0.9005 - 93ms/epoch - 1ms/step
# Epoch 42/100
# 79/79 - 0s - loss: 0.2357 - acc: 0.9676 - val_loss: 0.4097 - val_acc: 0.9053 - 89ms/epoch - 1ms/step
# Epoch 43/100
# 79/79 - 0s - loss: 0.2327 - acc: 0.9676 - val_loss: 0.4062 - val_acc: 0.9029 - 95ms/epoch - 1ms/step
# Epoch 44/100
# 79/79 - 0s - loss: 0.2305 - acc: 0.9708 - val_loss: 0.4058 - val_acc: 0.8993 - 96ms/epoch - 1ms/step
# Epoch 45/100
# 79/79 - 0s - loss: 0.2302 - acc: 0.9692 - val_loss: 0.4100 - val_acc: 0.9017 - 96ms/epoch - 1ms/step
# Epoch 46/100
# 79/79 - 0s - loss: 0.2261 - acc: 0.9716 - val_loss: 0.4126 - val_acc: 0.9005 - 100ms/epoch - 1ms/step
# Epoch 47/100
# 79/79 - 0s - loss: 0.2303 - acc: 0.9676 - val_loss: 0.4136 - val_acc: 0.9017 - 110ms/epoch - 1ms/step
# Epoch 48/100
# 79/79 - 0s - loss: 0.2245 - acc: 0.9708 - val_loss: 0.4139 - val_acc: 0.9005 - 96ms/epoch - 1ms/step
# Epoch 49/100
# 79/79 - 0s - loss: 0.2190 - acc: 0.9724 - val_loss: 0.4267 - val_acc: 0.8957 - 104ms/epoch - 1ms/step
# Epoch 50/100
# 79/79 - 0s - loss: 0.2202 - acc: 0.9716 - val_loss: 0.4260 - val_acc: 0.9005 - 94ms/epoch - 1ms/step
# Epoch 51/100
# 79/79 - 0s - loss: 0.2183 - acc: 0.9740 - val_loss: 0.4299 - val_acc: 0.8885 - 89ms/epoch - 1ms/step
# Epoch 52/100
# 79/79 - 0s - loss: 0.2146 - acc: 0.9732 - val_loss: 0.4201 - val_acc: 0.9089 - 92ms/epoch - 1ms/step
# Epoch 53/100
# 79/79 - 0s - loss: 0.2142 - acc: 0.9724 - val_loss: 0.4219 - val_acc: 0.9053 - 102ms/epoch - 1ms/step
# Epoch 54/100
# 79/79 - 0s - loss: 0.2112 - acc: 0.9772 - val_loss: 0.4256 - val_acc: 0.9029 - 107ms/epoch - 1ms/step
# Epoch 55/100
# 79/79 - 0s - loss: 0.2101 - acc: 0.9760 - val_loss: 0.4221 - val_acc: 0.9041 - 107ms/epoch - 1ms/step
# Epoch 56/100
# 79/79 - 0s - loss: 0.2070 - acc: 0.9776 - val_loss: 0.4403 - val_acc: 0.9017 - 132ms/epoch - 2ms/step
# Epoch 57/100
# 79/79 - 0s - loss: 0.2083 - acc: 0.9764 - val_loss: 0.4432 - val_acc: 0.8945 - 92ms/epoch - 1ms/step
# Epoch 58/100
# 79/79 - 0s - loss: 0.2045 - acc: 0.9788 - val_loss: 0.4406 - val_acc: 0.9017 - 97ms/epoch - 1ms/step
# Epoch 59/100
# 79/79 - 0s - loss: 0.2114 - acc: 0.9696 - val_loss: 0.4370 - val_acc: 0.9065 - 111ms/epoch - 1ms/step
# Epoch 60/100
# 79/79 - 0s - loss: 0.2029 - acc: 0.9796 - val_loss: 0.4493 - val_acc: 0.8981 - 125ms/epoch - 2ms/step
# Epoch 61/100
# 79/79 - 0s - loss: 0.2000 - acc: 0.9816 - val_loss: 0.4356 - val_acc: 0.9029 - 92ms/epoch - 1ms/step
# Epoch 62/100
# 79/79 - 0s - loss: 0.1975 - acc: 0.9780 - val_loss: 0.4584 - val_acc: 0.8957 - 97ms/epoch - 1ms/step
# Epoch 63/100
# 79/79 - 0s - loss: 0.1963 - acc: 0.9812 - val_loss: 0.4569 - val_acc: 0.8969 - 123ms/epoch - 2ms/step
# Epoch 64/100
# 79/79 - 0s - loss: 0.1941 - acc: 0.9812 - val_loss: 0.4561 - val_acc: 0.8921 - 119ms/epoch - 2ms/step
# Epoch 65/100
# 79/79 - 0s - loss: 0.1991 - acc: 0.9812 - val_loss: 0.4463 - val_acc: 0.9041 - 115ms/epoch - 1ms/step
# Epoch 66/100
# 79/79 - 0s - loss: 0.1924 - acc: 0.9836 - val_loss: 0.4621 - val_acc: 0.9017 - 115ms/epoch - 1ms/step
# Epoch 67/100
# 79/79 - 0s - loss: 0.1921 - acc: 0.9824 - val_loss: 0.4645 - val_acc: 0.9041 - 101ms/epoch - 1ms/step
# Epoch 68/100
# 79/79 - 0s - loss: 0.1941 - acc: 0.9812 - val_loss: 0.4619 - val_acc: 0.9017 - 96ms/epoch - 1ms/step
# Epoch 69/100
# 79/79 - 0s - loss: 0.1890 - acc: 0.9820 - val_loss: 0.4693 - val_acc: 0.9005 - 103ms/epoch - 1ms/step
# Epoch 70/100
# 79/79 - 0s - loss: 0.1905 - acc: 0.9836 - val_loss: 0.4582 - val_acc: 0.9077 - 156ms/epoch - 2ms/step
# Epoch 71/100
# 79/79 - 0s - loss: 0.2050 - acc: 0.9736 - val_loss: 0.4697 - val_acc: 0.8897 - 112ms/epoch - 1ms/step
# Epoch 72/100
# 79/79 - 0s - loss: 0.1934 - acc: 0.9824 - val_loss: 0.4689 - val_acc: 0.8993 - 94ms/epoch - 1ms/step
# Epoch 73/100
# 79/79 - 0s - loss: 0.1885 - acc: 0.9836 - val_loss: 0.4628 - val_acc: 0.8969 - 97ms/epoch - 1ms/step
# Epoch 74/100
# 79/79 - 0s - loss: 0.1836 - acc: 0.9860 - val_loss: 0.4664 - val_acc: 0.9017 - 95ms/epoch - 1ms/step
# Epoch 75/100
# 79/79 - 0s - loss: 0.1842 - acc: 0.9852 - val_loss: 0.4694 - val_acc: 0.9041 - 97ms/epoch - 1ms/step
# Epoch 76/100
# 79/79 - 0s - loss: 0.1792 - acc: 0.9880 - val_loss: 0.4754 - val_acc: 0.9017 - 92ms/epoch - 1ms/step
# Epoch 77/100
# 79/79 - 0s - loss: 0.1785 - acc: 0.9860 - val_loss: 0.4832 - val_acc: 0.8993 - 98ms/epoch - 1ms/step
# Epoch 78/100
# 79/79 - 0s - loss: 0.1757 - acc: 0.9888 - val_loss: 0.4750 - val_acc: 0.9053 - 96ms/epoch - 1ms/step
# Epoch 79/100
# 79/79 - 0s - loss: 0.1764 - acc: 0.9888 - val_loss: 0.4720 - val_acc: 0.9029 - 104ms/epoch - 1ms/step
# Epoch 80/100
# 79/79 - 0s - loss: 0.1772 - acc: 0.9880 - val_loss: 0.4840 - val_acc: 0.8969 - 100ms/epoch - 1ms/step
# Epoch 81/100
# 79/79 - 0s - loss: 0.1776 - acc: 0.9872 - val_loss: 0.4805 - val_acc: 0.8981 - 94ms/epoch - 1ms/step
# Epoch 82/100
# 79/79 - 0s - loss: 0.1734 - acc: 0.9904 - val_loss: 0.4795 - val_acc: 0.9101 - 99ms/epoch - 1ms/step
# Epoch 83/100
# 79/79 - 0s - loss: 0.1727 - acc: 0.9880 - val_loss: 0.4984 - val_acc: 0.9017 - 92ms/epoch - 1ms/step
# Epoch 84/100
# 79/79 - 0s - loss: 0.1879 - acc: 0.9808 - val_loss: 0.4852 - val_acc: 0.8981 - 93ms/epoch - 1ms/step
# Epoch 85/100
# 79/79 - 0s - loss: 0.1730 - acc: 0.9888 - val_loss: 0.4904 - val_acc: 0.8981 - 99ms/epoch - 1ms/step
# Epoch 86/100
# 79/79 - 0s - loss: 0.1810 - acc: 0.9864 - val_loss: 0.4981 - val_acc: 0.8981 - 98ms/epoch - 1ms/step
# Epoch 87/100
# 79/79 - 0s - loss: 0.1899 - acc: 0.9816 - val_loss: 0.4913 - val_acc: 0.8969 - 96ms/epoch - 1ms/step
# Epoch 88/100
# 79/79 - 0s - loss: 0.1746 - acc: 0.9892 - val_loss: 0.4956 - val_acc: 0.8969 - 97ms/epoch - 1ms/step
# Epoch 89/100
# 79/79 - 0s - loss: 0.1674 - acc: 0.9920 - val_loss: 0.4937 - val_acc: 0.8957 - 170ms/epoch - 2ms/step
# Epoch 90/100
# 79/79 - 0s - loss: 0.1661 - acc: 0.9920 - val_loss: 0.4974 - val_acc: 0.9029 - 116ms/epoch - 1ms/step
# Epoch 91/100
# 79/79 - 0s - loss: 0.1678 - acc: 0.9916 - val_loss: 0.4946 - val_acc: 0.9029 - 113ms/epoch - 1ms/step
# Epoch 92/100
# 79/79 - 0s - loss: 0.1662 - acc: 0.9904 - val_loss: 0.4988 - val_acc: 0.8993 - 126ms/epoch - 2ms/step
# Epoch 93/100
# 79/79 - 0s - loss: 0.1653 - acc: 0.9920 - val_loss: 0.5078 - val_acc: 0.8993 - 118ms/epoch - 1ms/step
# Epoch 94/100
# 79/79 - 0s - loss: 0.1637 - acc: 0.9924 - val_loss: 0.4929 - val_acc: 0.8933 - 105ms/epoch - 1ms/step
# Epoch 95/100
# 79/79 - 0s - loss: 0.1618 - acc: 0.9940 - val_loss: 0.5006 - val_acc: 0.8957 - 91ms/epoch - 1ms/step
# Epoch 96/100
# 79/79 - 0s - loss: 0.1761 - acc: 0.9860 - val_loss: 0.5062 - val_acc: 0.8993 - 90ms/epoch - 1ms/step
# Epoch 97/100
# 79/79 - 0s - loss: 0.1631 - acc: 0.9920 - val_loss: 0.4973 - val_acc: 0.9017 - 97ms/epoch - 1ms/step
# Epoch 98/100
# 79/79 - 0s - loss: 0.1680 - acc: 0.9904 - val_loss: 0.5089 - val_acc: 0.9005 - 98ms/epoch - 1ms/step
# Epoch 99/100
# 79/79 - 0s - loss: 0.1616 - acc: 0.9924 - val_loss: 0.5061 - val_acc: 0.9017 - 129ms/epoch - 2ms/step
# Epoch 100/100
# 79/79 - 0s - loss: 0.1595 - acc: 0.9940 - val_loss: 0.5129 - val_acc: 0.8981 - 127ms/epoch - 2ms/step

# %%
train_loss_l1 = history_l1.history['loss']
test_loss_l1 = history_l1.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_l1, label='L2 Training loss', color='darkred')
plt.plot(test_loss_l1, label='L2 Testing loss', color='pink')
plt.legend();

# %%
# from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l2,l1

model_l2 = Sequential()

n_input = X_train.shape[1]

model_l2.add(Dense(
    69,
    input_dim=n_input,
    activation='relu',
    kernel_regularizer=l2(0.001) # put in regulizers 
))

model_l2.add(Dense(
    20,
    activation='relu',
    kernel_regularizer=l2(0.001)
))

model_l2.add(Dense(
    1,
    activation='sigmoid',
    kernel_regularizer=l2(0.001)
))

model_l2.compile(
    loss='bce',
    optimizer='adam',
    metrics=['acc']
)

history_l2 = model_l2.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    verbose = 2
)
# Out:
# Epoch 1/100
# 79/79 - 1s - loss: 0.5879 - acc: 0.7899 - val_loss: 0.4844 - val_acc: 0.8549 - 590ms/epoch - 7ms/step
# Epoch 2/100
# 79/79 - 0s - loss: 0.4509 - acc: 0.8583 - val_loss: 0.4405 - val_acc: 0.8621 - 102ms/epoch - 1ms/step
# Epoch 3/100
# 79/79 - 0s - loss: 0.4048 - acc: 0.8667 - val_loss: 0.4150 - val_acc: 0.8669 - 104ms/epoch - 1ms/step
# Epoch 4/100
# 79/79 - 0s - loss: 0.3693 - acc: 0.8788 - val_loss: 0.3932 - val_acc: 0.8777 - 101ms/epoch - 1ms/step
# Epoch 5/100
# 79/79 - 0s - loss: 0.3379 - acc: 0.8972 - val_loss: 0.3737 - val_acc: 0.8813 - 95ms/epoch - 1ms/step
# Epoch 6/100
# 79/79 - 0s - loss: 0.3089 - acc: 0.9064 - val_loss: 0.3579 - val_acc: 0.8825 - 99ms/epoch - 1ms/step
# Epoch 7/100
# 79/79 - 0s - loss: 0.2821 - acc: 0.9240 - val_loss: 0.3495 - val_acc: 0.8921 - 95ms/epoch - 1ms/step
# Epoch 8/100
# 79/79 - 0s - loss: 0.2616 - acc: 0.9320 - val_loss: 0.3466 - val_acc: 0.8897 - 101ms/epoch - 1ms/step
# Epoch 9/100
# 79/79 - 0s - loss: 0.2513 - acc: 0.9340 - val_loss: 0.3440 - val_acc: 0.8921 - 117ms/epoch - 1ms/step
# Epoch 10/100
# 79/79 - 0s - loss: 0.2315 - acc: 0.9500 - val_loss: 0.3490 - val_acc: 0.8909 - 92ms/epoch - 1ms/step
# Epoch 11/100
# 79/79 - 0s - loss: 0.2247 - acc: 0.9448 - val_loss: 0.3435 - val_acc: 0.8969 - 94ms/epoch - 1ms/step
# Epoch 12/100
# 79/79 - 0s - loss: 0.2122 - acc: 0.9516 - val_loss: 0.3503 - val_acc: 0.8969 - 94ms/epoch - 1ms/step
# Epoch 13/100
# 79/79 - 0s - loss: 0.2004 - acc: 0.9576 - val_loss: 0.3539 - val_acc: 0.8945 - 97ms/epoch - 1ms/step
# Epoch 14/100
# 79/79 - 0s - loss: 0.1926 - acc: 0.9584 - val_loss: 0.3500 - val_acc: 0.9041 - 94ms/epoch - 1ms/step
# Epoch 15/100
# 79/79 - 0s - loss: 0.1822 - acc: 0.9692 - val_loss: 0.3622 - val_acc: 0.8957 - 93ms/epoch - 1ms/step
# Epoch 16/100
# 79/79 - 0s - loss: 0.1775 - acc: 0.9680 - val_loss: 0.3564 - val_acc: 0.9017 - 95ms/epoch - 1ms/step
# Epoch 17/100
# 79/79 - 0s - loss: 0.1688 - acc: 0.9724 - val_loss: 0.3604 - val_acc: 0.9005 - 93ms/epoch - 1ms/step
# Epoch 18/100
# 79/79 - 0s - loss: 0.1639 - acc: 0.9748 - val_loss: 0.3607 - val_acc: 0.9077 - 95ms/epoch - 1ms/step
# Epoch 19/100
# 79/79 - 0s - loss: 0.1574 - acc: 0.9788 - val_loss: 0.3686 - val_acc: 0.9053 - 93ms/epoch - 1ms/step
# Epoch 20/100
# 79/79 - 0s - loss: 0.1582 - acc: 0.9756 - val_loss: 0.3752 - val_acc: 0.9017 - 92ms/epoch - 1ms/step
# Epoch 21/100
# 79/79 - 0s - loss: 0.1453 - acc: 0.9812 - val_loss: 0.3781 - val_acc: 0.8945 - 99ms/epoch - 1ms/step
# Epoch 22/100
# 79/79 - 0s - loss: 0.1449 - acc: 0.9804 - val_loss: 0.3875 - val_acc: 0.8957 - 95ms/epoch - 1ms/step
# Epoch 23/100
# 79/79 - 0s - loss: 0.1365 - acc: 0.9848 - val_loss: 0.3918 - val_acc: 0.8933 - 96ms/epoch - 1ms/step
# Epoch 24/100
# 79/79 - 0s - loss: 0.1324 - acc: 0.9832 - val_loss: 0.3871 - val_acc: 0.8969 - 91ms/epoch - 1ms/step
# Epoch 25/100
# 79/79 - 0s - loss: 0.1292 - acc: 0.9844 - val_loss: 0.3966 - val_acc: 0.9005 - 95ms/epoch - 1ms/step
# Epoch 26/100
# 79/79 - 0s - loss: 0.1269 - acc: 0.9844 - val_loss: 0.4075 - val_acc: 0.8969 - 95ms/epoch - 1ms/step
# Epoch 27/100
# 79/79 - 0s - loss: 0.1238 - acc: 0.9880 - val_loss: 0.4040 - val_acc: 0.9053 - 93ms/epoch - 1ms/step
# Epoch 28/100
# 79/79 - 0s - loss: 0.1194 - acc: 0.9888 - val_loss: 0.4038 - val_acc: 0.9029 - 96ms/epoch - 1ms/step
# Epoch 29/100
# 79/79 - 0s - loss: 0.1173 - acc: 0.9908 - val_loss: 0.4042 - val_acc: 0.9041 - 96ms/epoch - 1ms/step
# Epoch 30/100
# 79/79 - 0s - loss: 0.1150 - acc: 0.9912 - val_loss: 0.4073 - val_acc: 0.9089 - 99ms/epoch - 1ms/step
# Epoch 31/100
# 79/79 - 0s - loss: 0.1127 - acc: 0.9904 - val_loss: 0.4224 - val_acc: 0.8897 - 102ms/epoch - 1ms/step
# Epoch 32/100
# 79/79 - 0s - loss: 0.1119 - acc: 0.9916 - val_loss: 0.4255 - val_acc: 0.9005 - 96ms/epoch - 1ms/step
# Epoch 33/100
# 79/79 - 0s - loss: 0.1108 - acc: 0.9928 - val_loss: 0.4257 - val_acc: 0.9005 - 97ms/epoch - 1ms/step
# Epoch 34/100
# 79/79 - 0s - loss: 0.1071 - acc: 0.9924 - val_loss: 0.4336 - val_acc: 0.8969 - 93ms/epoch - 1ms/step
# Epoch 35/100
# 79/79 - 0s - loss: 0.1040 - acc: 0.9932 - val_loss: 0.4201 - val_acc: 0.9029 - 99ms/epoch - 1ms/step
# Epoch 36/100
# 79/79 - 0s - loss: 0.1023 - acc: 0.9936 - val_loss: 0.4387 - val_acc: 0.8945 - 100ms/epoch - 1ms/step
# Epoch 37/100
# 79/79 - 0s - loss: 0.1045 - acc: 0.9940 - val_loss: 0.4413 - val_acc: 0.8945 - 98ms/epoch - 1ms/step
# Epoch 38/100
# 79/79 - 0s - loss: 0.1101 - acc: 0.9900 - val_loss: 0.4415 - val_acc: 0.8969 - 96ms/epoch - 1ms/step
# Epoch 39/100
# 79/79 - 0s - loss: 0.1015 - acc: 0.9948 - val_loss: 0.4380 - val_acc: 0.8981 - 99ms/epoch - 1ms/step
# Epoch 40/100
# 79/79 - 0s - loss: 0.0976 - acc: 0.9960 - val_loss: 0.4369 - val_acc: 0.8957 - 101ms/epoch - 1ms/step
# Epoch 41/100
# 79/79 - 0s - loss: 0.0960 - acc: 0.9956 - val_loss: 0.4478 - val_acc: 0.8969 - 93ms/epoch - 1ms/step
# Epoch 42/100
# 79/79 - 0s - loss: 0.0986 - acc: 0.9944 - val_loss: 0.4530 - val_acc: 0.8897 - 96ms/epoch - 1ms/step
# Epoch 43/100
# 79/79 - 0s - loss: 0.0925 - acc: 0.9964 - val_loss: 0.4447 - val_acc: 0.8933 - 106ms/epoch - 1ms/step
# Epoch 44/100
# 79/79 - 0s - loss: 0.0918 - acc: 0.9964 - val_loss: 0.4544 - val_acc: 0.8945 - 99ms/epoch - 1ms/step
# Epoch 45/100
# 79/79 - 0s - loss: 0.0918 - acc: 0.9968 - val_loss: 0.4571 - val_acc: 0.8993 - 96ms/epoch - 1ms/step
# Epoch 46/100
# 79/79 - 0s - loss: 0.0908 - acc: 0.9964 - val_loss: 0.4559 - val_acc: 0.8897 - 93ms/epoch - 1ms/step
# Epoch 47/100
# 79/79 - 0s - loss: 0.0896 - acc: 0.9968 - val_loss: 0.4398 - val_acc: 0.8969 - 96ms/epoch - 1ms/step
# Epoch 48/100
# 79/79 - 0s - loss: 0.0889 - acc: 0.9976 - val_loss: 0.4437 - val_acc: 0.8981 - 96ms/epoch - 1ms/step
# Epoch 49/100
# 79/79 - 0s - loss: 0.0883 - acc: 0.9968 - val_loss: 0.4548 - val_acc: 0.8933 - 99ms/epoch - 1ms/step
# Epoch 50/100
# 79/79 - 0s - loss: 0.0878 - acc: 0.9968 - val_loss: 0.4520 - val_acc: 0.8957 - 97ms/epoch - 1ms/step
# Epoch 51/100
# 79/79 - 0s - loss: 0.0876 - acc: 0.9964 - val_loss: 0.4608 - val_acc: 0.8897 - 100ms/epoch - 1ms/step
# Epoch 52/100
# 79/79 - 0s - loss: 0.0858 - acc: 0.9980 - val_loss: 0.4556 - val_acc: 0.9005 - 92ms/epoch - 1ms/step
# Epoch 53/100
# 79/79 - 0s - loss: 0.0843 - acc: 0.9976 - val_loss: 0.4442 - val_acc: 0.9041 - 94ms/epoch - 1ms/step
# Epoch 54/100
# 79/79 - 0s - loss: 0.0919 - acc: 0.9956 - val_loss: 0.4564 - val_acc: 0.8957 - 97ms/epoch - 1ms/step
# Epoch 55/100
# 79/79 - 0s - loss: 0.0846 - acc: 0.9988 - val_loss: 0.4446 - val_acc: 0.9005 - 96ms/epoch - 1ms/step
# Epoch 56/100
# 79/79 - 0s - loss: 0.0829 - acc: 0.9988 - val_loss: 0.4504 - val_acc: 0.8981 - 97ms/epoch - 1ms/step
# Epoch 57/100
# 79/79 - 0s - loss: 0.0828 - acc: 0.9980 - val_loss: 0.4520 - val_acc: 0.8945 - 93ms/epoch - 1ms/step
# Epoch 58/100
# 79/79 - 0s - loss: 0.0813 - acc: 0.9992 - val_loss: 0.4561 - val_acc: 0.8945 - 95ms/epoch - 1ms/step
# Epoch 59/100
# 79/79 - 0s - loss: 0.0829 - acc: 0.9976 - val_loss: 0.4648 - val_acc: 0.8957 - 90ms/epoch - 1ms/step
# Epoch 60/100
# 79/79 - 0s - loss: 0.0802 - acc: 0.9980 - val_loss: 0.4752 - val_acc: 0.8957 - 94ms/epoch - 1ms/step
# Epoch 61/100
# 79/79 - 0s - loss: 0.0792 - acc: 0.9992 - val_loss: 0.4635 - val_acc: 0.8969 - 100ms/epoch - 1ms/step
# Epoch 62/100
# 79/79 - 0s - loss: 0.0785 - acc: 0.9996 - val_loss: 0.4678 - val_acc: 0.8981 - 107ms/epoch - 1ms/step
# Epoch 63/100
# 79/79 - 0s - loss: 0.0839 - acc: 0.9964 - val_loss: 0.4882 - val_acc: 0.8897 - 98ms/epoch - 1ms/step
# Epoch 64/100
# 79/79 - 0s - loss: 0.0818 - acc: 0.9984 - val_loss: 0.4652 - val_acc: 0.8969 - 91ms/epoch - 1ms/step
# Epoch 65/100
# 79/79 - 0s - loss: 0.0798 - acc: 0.9976 - val_loss: 0.4667 - val_acc: 0.8969 - 91ms/epoch - 1ms/step
# Epoch 66/100
# 79/79 - 0s - loss: 0.0784 - acc: 0.9988 - val_loss: 0.4519 - val_acc: 0.8981 - 96ms/epoch - 1ms/step
# Epoch 67/100
# 79/79 - 0s - loss: 0.0782 - acc: 0.9988 - val_loss: 0.4736 - val_acc: 0.8933 - 95ms/epoch - 1ms/step
# Epoch 68/100
# 79/79 - 0s - loss: 0.0868 - acc: 0.9952 - val_loss: 0.4924 - val_acc: 0.8885 - 97ms/epoch - 1ms/step
# Epoch 69/100
# 79/79 - 0s - loss: 0.0826 - acc: 0.9972 - val_loss: 0.4852 - val_acc: 0.8921 - 109ms/epoch - 1ms/step
# Epoch 70/100
# 79/79 - 0s - loss: 0.0795 - acc: 0.9992 - val_loss: 0.4742 - val_acc: 0.8993 - 93ms/epoch - 1ms/step
# Epoch 71/100
# 79/79 - 0s - loss: 0.0751 - acc: 0.9992 - val_loss: 0.4698 - val_acc: 0.8945 - 92ms/epoch - 1ms/step
# Epoch 72/100
# 79/79 - 0s - loss: 0.0795 - acc: 0.9964 - val_loss: 0.4733 - val_acc: 0.8981 - 98ms/epoch - 1ms/step
# Epoch 73/100
# 79/79 - 0s - loss: 0.0765 - acc: 0.9984 - val_loss: 0.4808 - val_acc: 0.8933 - 97ms/epoch - 1ms/step
# Epoch 74/100
# 79/79 - 0s - loss: 0.0747 - acc: 0.9992 - val_loss: 0.4653 - val_acc: 0.8945 - 93ms/epoch - 1ms/step
# Epoch 75/100
# 79/79 - 0s - loss: 0.0741 - acc: 0.9996 - val_loss: 0.4801 - val_acc: 0.8921 - 96ms/epoch - 1ms/step
# Epoch 76/100
# 79/79 - 0s - loss: 0.0758 - acc: 0.9976 - val_loss: 0.4794 - val_acc: 0.8933 - 91ms/epoch - 1ms/step
# Epoch 77/100
# 79/79 - 0s - loss: 0.0778 - acc: 0.9976 - val_loss: 0.4681 - val_acc: 0.8849 - 91ms/epoch - 1ms/step
# Epoch 78/100
# 79/79 - 0s - loss: 0.0792 - acc: 0.9984 - val_loss: 0.4678 - val_acc: 0.8933 - 93ms/epoch - 1ms/step
# Epoch 79/100
# 79/79 - 0s - loss: 0.0799 - acc: 0.9968 - val_loss: 0.4966 - val_acc: 0.8801 - 98ms/epoch - 1ms/step
# Epoch 80/100
# 79/79 - 0s - loss: 0.0773 - acc: 0.9968 - val_loss: 0.4729 - val_acc: 0.8969 - 94ms/epoch - 1ms/step
# Epoch 81/100
# 79/79 - 0s - loss: 0.0737 - acc: 0.9996 - val_loss: 0.4777 - val_acc: 0.8885 - 99ms/epoch - 1ms/step
# Epoch 82/100
# 79/79 - 0s - loss: 0.0722 - acc: 0.9996 - val_loss: 0.4759 - val_acc: 0.8945 - 119ms/epoch - 2ms/step
# Epoch 83/100
# 79/79 - 0s - loss: 0.0712 - acc: 1.0000 - val_loss: 0.4754 - val_acc: 0.8969 - 135ms/epoch - 2ms/step
# Epoch 84/100
# 79/79 - 0s - loss: 0.0718 - acc: 0.9992 - val_loss: 0.4597 - val_acc: 0.8921 - 107ms/epoch - 1ms/step
# Epoch 85/100
# 79/79 - 0s - loss: 0.0746 - acc: 0.9976 - val_loss: 0.4792 - val_acc: 0.8969 - 97ms/epoch - 1ms/step
# Epoch 86/100
# 79/79 - 0s - loss: 0.0735 - acc: 0.9984 - val_loss: 0.4759 - val_acc: 0.9005 - 127ms/epoch - 2ms/step
# Epoch 87/100
# 79/79 - 0s - loss: 0.0722 - acc: 0.9984 - val_loss: 0.4734 - val_acc: 0.8969 - 101ms/epoch - 1ms/step
# Epoch 88/100
# 79/79 - 0s - loss: 0.0729 - acc: 0.9984 - val_loss: 0.4769 - val_acc: 0.8969 - 97ms/epoch - 1ms/step
# Epoch 89/100
# 79/79 - 0s - loss: 0.0744 - acc: 0.9976 - val_loss: 0.4826 - val_acc: 0.8897 - 90ms/epoch - 1ms/step
# Epoch 90/100
# 79/79 - 0s - loss: 0.0711 - acc: 0.9992 - val_loss: 0.4563 - val_acc: 0.8909 - 99ms/epoch - 1ms/step
# Epoch 91/100
# 79/79 - 0s - loss: 0.0712 - acc: 0.9992 - val_loss: 0.4644 - val_acc: 0.9041 - 99ms/epoch - 1ms/step
# Epoch 92/100
# 79/79 - 0s - loss: 0.0714 - acc: 0.9988 - val_loss: 0.4805 - val_acc: 0.8909 - 100ms/epoch - 1ms/step
# Epoch 93/100
# 79/79 - 0s - loss: 0.0702 - acc: 0.9996 - val_loss: 0.4713 - val_acc: 0.8957 - 104ms/epoch - 1ms/step
# Epoch 94/100
# 79/79 - 0s - loss: 0.0702 - acc: 0.9992 - val_loss: 0.4704 - val_acc: 0.8957 - 96ms/epoch - 1ms/step
# Epoch 95/100
# 79/79 - 0s - loss: 0.0716 - acc: 0.9984 - val_loss: 0.4784 - val_acc: 0.8765 - 101ms/epoch - 1ms/step
# Epoch 96/100
# 79/79 - 0s - loss: 0.0770 - acc: 0.9968 - val_loss: 0.4580 - val_acc: 0.8993 - 100ms/epoch - 1ms/step
# Epoch 97/100
# 79/79 - 0s - loss: 0.0753 - acc: 0.9972 - val_loss: 0.4869 - val_acc: 0.8933 - 92ms/epoch - 1ms/step
# Epoch 98/100
# 79/79 - 0s - loss: 0.0744 - acc: 0.9984 - val_loss: 0.4750 - val_acc: 0.8873 - 94ms/epoch - 1ms/step
# Epoch 99/100
# 79/79 - 0s - loss: 0.0736 - acc: 0.9984 - val_loss: 0.4717 - val_acc: 0.8909 - 92ms/epoch - 1ms/step
# Epoch 100/100
# 79/79 - 0s - loss: 0.0704 - acc: 0.9996 - val_loss: 0.4820 - val_acc: 0.8945 - 102ms/epoch - 1ms/step

# %%
train_loss_l2 = history_l2.history['loss']
test_loss_l2 = history_l2.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_l2, label='L2 Training loss', color='darkred')
plt.plot(test_loss_l2, label='L2 Testing loss', color='pink')
plt.legend();

# %%
history_l2.history['acc'][-1], history_l2.history['val_acc'][-1]
# Out:
# (0.999599814414978, 0.8944844007492065)

# %% [markdown]
# ## Keras Resources
# - [Keras Regularization Documentation](https://keras.io/regularizers/)
# - [Kernel vs. Activity Regularizers](https://github.com/keras-team/keras/issues/3236)
#
# ## Tensorflow Resources
# - [Implementation in Tensorflow](https://www.tensorflow.org/versions/r0.12/api_docs/python/contrib.layers/regularizers)
# - [Example in Tensorflow](http://www.ritchieng.com/machine-learning/deep-learning/tensorflow/regularization/)

# %% [markdown]
# <a id='dropout'></a>
# ## Regularization Method 2: Dropout
# ---
# There's another method of regularizing our terms that is specifically designed for neural networks, called **dropout regularization.**

# %% [markdown]
# Let's say we've constructed a neural network. We've decided on the number of layers we want and the number of nodes in each layer. (We might say that we've decided on the **topology** or **structure** of our network.)
#
# ![](../assets/original_nn.jpeg)
#
# However, a densely connected network like this will almost certainly overfit. Our network is learning a parameter for every single connection.
#
# > In the above example, we have 55 parameters being learned - and this is a very simple network, all things considered.
#
# > We can overcome this by using **dropout regularization**.
#
# In dropout regularization, we randomly **drop** units (nodes) in our neural network ***during our training phase only***. We assign a probability of each node disappearing. Then, we essentially perform a coinflip for every node to turn that node "on" or "off."
#
# Let's go through an example to illustrate this: For simplicity, we'll say we've assigned a 0.5 probability of keeping to every node in the network above. Then, for every node, we flip a coin, and if the coin lands on heads, the node remains, if it lands on tails, the node disappears. After we've done this for every node, we're left with a new network that looks something like this:
#
# ![](../assets/after_dropout.jpeg)
#
# <!--
# Image sources: https://pgaleone.eu/deep-learning/regularization/2017/01/10/anaysis-of-dropout/
# Also, it seems, this site: http://cs231n.github.io/neural-networks-2/
# -->
#
# Let's explicitly lay out the general workflow you would follow:
#
# 1. Specify the topology of your neural network.
# 2. Initialize your weights and biases.
# 3. Specify the "keeping probabilities" for every node. (Generally, we'll assign the same probability to all nodes in each layer and usually the same probability to all hidden layers.)
# 4. Perform a "coin flip" for each node and drop out the chosen nodes.
# 5. Run through one epoch of training.
# 6. Repeat steps 4 and 5 for each epoch of training.

# %% [markdown]
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2018/04/1IrdJ5PghD9YoOyVAQ73MJw.gif)

# %% [markdown]
# <details><summary>If I drop out a node during one of my epochs, does it disappear from my final network?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### So, what does this do?
# <!-- <br/> -->
# The intuition behind dropout is that, since each node has a probability of disappearing at any time, the neural network is disincentivized from allocating too much power to any one weight. It has a similar effect as imposing an L2 penalty: the magnitude of our weights shrinks.

# %% [markdown]
# <details><summary>What might be some potential problems with doing this?</summary>
#
# - expected values of nodes changes
# - induces bias
# </details>

# %% [markdown]
# So we've now run through every epoch of our training phase and we're ready to apply our neural network to our validation or testing data.
#
# <details><summary>Are we going to apply dropout to this data as well?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### Best practices:
#
# - Don't set any keeping probabilities for layers you where you don't want to drop any nodes.
#
# <details><summary>What might be examples of these layers?</summary>
#
# - Input layers
# - Output layers
# </details>

# %% [markdown]
# - You'll generally want to specify a single keeping probability and all the layers on which you want to apply dropout, instead of specifying different keeping probabilities for each layer.

# %%
X_train.shape[1]
# Out:
# 69

# %%
from tensorflow.keras.layers import Dropout

model_dropout = Sequential()

n_input = X_train.shape[1]
n_hidden = n_input

model_dropout.add(Dense(n_hidden, input_dim=n_input, activation='relu')) # 69 nodes from input
model_dropout.add(Dropout(0.2)) # refers to nodes in the first hidden layer 0.2 probability switching off 
                                # on ave, 14 notes will be on
model_dropout.add(Dense(20, activation='relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(1, activation='sigmoid'))

model_dropout.compile(loss='bce', optimizer='adam', metrics=['acc'])

history_dropout = model_dropout.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test), 
    epochs=100,
    batch_size=None
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 1s 3ms/step - loss: 0.5124 - acc: 0.7743 - val_loss: 0.3951 - val_acc: 0.8561
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4076 - acc: 0.8559 - val_loss: 0.3671 - val_acc: 0.8585
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3690 - acc: 0.8599 - val_loss: 0.3494 - val_acc: 0.8609
# Epoch 4/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.3510 - acc: 0.8623 - val_loss: 0.3425 - val_acc: 0.8609
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3315 - acc: 0.8699 - val_loss: 0.3310 - val_acc: 0.8729
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3151 - acc: 0.8739 - val_loss: 0.3262 - val_acc: 0.8729
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3036 - acc: 0.8764 - val_loss: 0.3186 - val_acc: 0.8741
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2872 - acc: 0.8924 - val_loss: 0.3066 - val_acc: 0.8789
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2729 - acc: 0.8884 - val_loss: 0.3001 - val_acc: 0.8765
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2656 - acc: 0.8996 - val_loss: 0.2960 - val_acc: 0.8813
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2487 - acc: 0.9096 - val_loss: 0.2885 - val_acc: 0.8897
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2431 - acc: 0.9092 - val_loss: 0.2842 - val_acc: 0.8921
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2349 - acc: 0.9080 - val_loss: 0.2798 - val_acc: 0.8993
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2286 - acc: 0.9140 - val_loss: 0.2869 - val_acc: 0.8921
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2209 - acc: 0.9160 - val_loss: 0.2804 - val_acc: 0.8957
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2043 - acc: 0.9256 - val_loss: 0.2856 - val_acc: 0.8897
# Epoch 17/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.2068 - acc: 0.9260 - val_loss: 0.2824 - val_acc: 0.9005
# Epoch 18/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1903 - acc: 0.9296 - val_loss: 0.2834 - val_acc: 0.8993
# Epoch 19/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1936 - acc: 0.9268 - val_loss: 0.2841 - val_acc: 0.9041
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1916 - acc: 0.9300 - val_loss: 0.2830 - val_acc: 0.8981
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1915 - acc: 0.9284 - val_loss: 0.2879 - val_acc: 0.9029
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1731 - acc: 0.9380 - val_loss: 0.2904 - val_acc: 0.9005
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1646 - acc: 0.9364 - val_loss: 0.2929 - val_acc: 0.8993
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1743 - acc: 0.9340 - val_loss: 0.2971 - val_acc: 0.8993
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1650 - acc: 0.9372 - val_loss: 0.2934 - val_acc: 0.9005
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1614 - acc: 0.9404 - val_loss: 0.2981 - val_acc: 0.9065
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1511 - acc: 0.9484 - val_loss: 0.2914 - val_acc: 0.9053
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1574 - acc: 0.9428 - val_loss: 0.3015 - val_acc: 0.9041
# Epoch 29/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1543 - acc: 0.9428 - val_loss: 0.2966 - val_acc: 0.9005
# Epoch 30/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1460 - acc: 0.9480 - val_loss: 0.3065 - val_acc: 0.9053
# Epoch 31/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1397 - acc: 0.9512 - val_loss: 0.3100 - val_acc: 0.9065
# Epoch 32/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1388 - acc: 0.9472 - val_loss: 0.3126 - val_acc: 0.9065
# Epoch 33/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1323 - acc: 0.9520 - val_loss: 0.3199 - val_acc: 0.9065
# Epoch 34/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1391 - acc: 0.9524 - val_loss: 0.3204 - val_acc: 0.9065
# Epoch 35/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1322 - acc: 0.9524 - val_loss: 0.3267 - val_acc: 0.9029
# Epoch 36/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1220 - acc: 0.9552 - val_loss: 0.3424 - val_acc: 0.9065
# Epoch 37/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1238 - acc: 0.9548 - val_loss: 0.3449 - val_acc: 0.9053
# Epoch 38/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1272 - acc: 0.9548 - val_loss: 0.3368 - val_acc: 0.9077
# Epoch 39/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1140 - acc: 0.9564 - val_loss: 0.3512 - val_acc: 0.9101
# Epoch 40/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1094 - acc: 0.9560 - val_loss: 0.3443 - val_acc: 0.9089
# Epoch 41/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1151 - acc: 0.9612 - val_loss: 0.3507 - val_acc: 0.9017
# Epoch 42/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1093 - acc: 0.9588 - val_loss: 0.3666 - val_acc: 0.9053
# Epoch 43/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1093 - acc: 0.9612 - val_loss: 0.3712 - val_acc: 0.8993
# Epoch 44/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1101 - acc: 0.9528 - val_loss: 0.3658 - val_acc: 0.8981
# Epoch 45/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1153 - acc: 0.9556 - val_loss: 0.3667 - val_acc: 0.9005
# Epoch 46/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1048 - acc: 0.9600 - val_loss: 0.3770 - val_acc: 0.9041
# Epoch 47/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1000 - acc: 0.9604 - val_loss: 0.3873 - val_acc: 0.9017
# Epoch 48/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0959 - acc: 0.9656 - val_loss: 0.3927 - val_acc: 0.8993
# Epoch 49/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0931 - acc: 0.9640 - val_loss: 0.3977 - val_acc: 0.8969
# Epoch 50/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1037 - acc: 0.9604 - val_loss: 0.4057 - val_acc: 0.9017
# Epoch 51/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0992 - acc: 0.9632 - val_loss: 0.3980 - val_acc: 0.9017
# Epoch 52/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0865 - acc: 0.9692 - val_loss: 0.4069 - val_acc: 0.9005
# Epoch 53/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0881 - acc: 0.9672 - val_loss: 0.4250 - val_acc: 0.9053
# Epoch 54/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0907 - acc: 0.9652 - val_loss: 0.4211 - val_acc: 0.9005
# Epoch 55/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0839 - acc: 0.9688 - val_loss: 0.4348 - val_acc: 0.9017
# Epoch 56/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0955 - acc: 0.9660 - val_loss: 0.4303 - val_acc: 0.9017
# Epoch 57/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0858 - acc: 0.9644 - val_loss: 0.4203 - val_acc: 0.8957
# Epoch 58/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0820 - acc: 0.9696 - val_loss: 0.4495 - val_acc: 0.8981
# Epoch 59/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0878 - acc: 0.9664 - val_loss: 0.4472 - val_acc: 0.8993
# Epoch 60/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0796 - acc: 0.9708 - val_loss: 0.4439 - val_acc: 0.8981
# Epoch 61/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0770 - acc: 0.9712 - val_loss: 0.4442 - val_acc: 0.9029
# Epoch 62/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0820 - acc: 0.9664 - val_loss: 0.4580 - val_acc: 0.9017
# Epoch 63/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0795 - acc: 0.9668 - val_loss: 0.4326 - val_acc: 0.9017
# Epoch 64/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0709 - acc: 0.9744 - val_loss: 0.4584 - val_acc: 0.9041
# Epoch 65/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0726 - acc: 0.9728 - val_loss: 0.4719 - val_acc: 0.9053
# Epoch 66/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0668 - acc: 0.9752 - val_loss: 0.4774 - val_acc: 0.9017
# Epoch 67/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0686 - acc: 0.9704 - val_loss: 0.4932 - val_acc: 0.8993
# Epoch 68/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0727 - acc: 0.9740 - val_loss: 0.4817 - val_acc: 0.9017
# Epoch 69/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0697 - acc: 0.9740 - val_loss: 0.4796 - val_acc: 0.9029
# Epoch 70/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0592 - acc: 0.9792 - val_loss: 0.4883 - val_acc: 0.9017
# Epoch 71/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0693 - acc: 0.9760 - val_loss: 0.4858 - val_acc: 0.9017
# Epoch 72/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0751 - acc: 0.9700 - val_loss: 0.4951 - val_acc: 0.8993
# Epoch 73/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0672 - acc: 0.9720 - val_loss: 0.4959 - val_acc: 0.9041
# Epoch 74/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0597 - acc: 0.9780 - val_loss: 0.5101 - val_acc: 0.9017
# Epoch 75/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0602 - acc: 0.9788 - val_loss: 0.5062 - val_acc: 0.9029
# Epoch 76/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0678 - acc: 0.9772 - val_loss: 0.5221 - val_acc: 0.8981
# Epoch 77/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0644 - acc: 0.9748 - val_loss: 0.5265 - val_acc: 0.9005
# Epoch 78/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0599 - acc: 0.9772 - val_loss: 0.5085 - val_acc: 0.9041
# Epoch 79/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0575 - acc: 0.9776 - val_loss: 0.5078 - val_acc: 0.8993
# Epoch 80/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0594 - acc: 0.9748 - val_loss: 0.5186 - val_acc: 0.8981
# Epoch 81/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0668 - acc: 0.9732 - val_loss: 0.5408 - val_acc: 0.9041
# Epoch 82/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0618 - acc: 0.9788 - val_loss: 0.5327 - val_acc: 0.9017
# Epoch 83/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0560 - acc: 0.9756 - val_loss: 0.5401 - val_acc: 0.9005
# Epoch 84/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0640 - acc: 0.9744 - val_loss: 0.5515 - val_acc: 0.8969
# Epoch 85/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0648 - acc: 0.9764 - val_loss: 0.5406 - val_acc: 0.9005
# Epoch 86/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0533 - acc: 0.9832 - val_loss: 0.5400 - val_acc: 0.9029
# Epoch 87/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0558 - acc: 0.9804 - val_loss: 0.5536 - val_acc: 0.9017
# Epoch 88/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.0484 - acc: 0.9840 - val_loss: 0.5458 - val_acc: 0.9065
# Epoch 89/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0557 - acc: 0.9800 - val_loss: 0.5560 - val_acc: 0.9041
# Epoch 90/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0473 - acc: 0.9832 - val_loss: 0.5405 - val_acc: 0.9005
# Epoch 91/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0507 - acc: 0.9828 - val_loss: 0.5554 - val_acc: 0.9053
# Epoch 92/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0503 - acc: 0.9804 - val_loss: 0.5624 - val_acc: 0.9005
# Epoch 93/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0531 - acc: 0.9808 - val_loss: 0.5639 - val_acc: 0.9053
# Epoch 94/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0514 - acc: 0.9800 - val_loss: 0.5657 - val_acc: 0.9053
# Epoch 95/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0587 - acc: 0.9788 - val_loss: 0.5615 - val_acc: 0.9029
# Epoch 96/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0521 - acc: 0.9812 - val_loss: 0.5547 - val_acc: 0.9041
# Epoch 97/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0432 - acc: 0.9832 - val_loss: 0.5794 - val_acc: 0.9041
# Epoch 98/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0536 - acc: 0.9784 - val_loss: 0.5827 - val_acc: 0.9005
# Epoch 99/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0447 - acc: 0.9828 - val_loss: 0.5932 - val_acc: 0.8981
# Epoch 100/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0509 - acc: 0.9792 - val_loss: 0.5794 - val_acc: 0.8969

# %%
train_loss_dropout = history_dropout.history['loss']
test_loss_dropout = history_dropout.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_dropout, label='Dropout Training loss', color='darkgreen')
plt.plot(test_loss_dropout, label='Dropout Testing loss', color='lightgreen')
plt.legend();

# %%
history_dropout.history['acc'][-1], history_dropout.history['val_acc'][-1]
# Out:
# (0.9791916608810425, 0.8968824744224548)

# %% [markdown]
# ## Keras Resources
# - [Keras Dropout Documentation](https://keras.io/layers/core/#dropout)
#
# ## Tensorflow Resources
# - [Tensorflow documentation](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)
# - [List of examples in Tensorflow](https://programtalk.com/python-examples/tensorflow.nn.dropout/)

# %% [markdown]
# <a id='stopping'></a>
# ## Regularization Method 3: Early Stopping
# ---
# The third method of regularization that we'll discuss today is called early stopping.
# </br>
# If we run though all our epochs of training and plot both our training and validation error, we'll typically see something like this:
#
# ![](../assets/train-val-error-reduced.png)
# *source*: [Prechelt, 1997](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf)

# %% [markdown]
# <details><summary>What is happening in this plot?</summary>
#
# - The Validation error begins to increase after a certain number of epochs!
# </details>

# %% [markdown]
# Early stopping does exactly what its name implies: it stop the training process early. Instead of continuing training through every epoch, once the validation error begins to increase, our algorithm stops because it has (in theory) found the minimum for the validation loss.
#
# This might seem like a simple and robust solution to overfitting, but it can run into problems.
#
# ![](../assets/validation-error-real.png)
#
# There is debate over how often this problem occurs. You can generally plot both the training and validation loss, see if you're getting multiple optima. If you are, there are multiple suggested techniques to combat this problem in the [paper reference above](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf).

# %%
X_train.shape[1]
# Out:
# 69

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_es = Sequential()

n_input = X_train.shape[1]

model_es.add(Dense(20, input_dim=n_input, activation='relu'))
model_es.add(Dense(1, activation='sigmoid'))

model_es.compile(loss='bce', optimizer='adam', metrics=['acc'])

early_stop = EarlyStopping(
    monitor='val_loss',
    min_delta=0, # if value is 0.002 -> loss must be decreasing by 0.002 in order not to stop
    patience=5,
    verbose=1,
    mode='auto')

history_es = model_es.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 1s 2ms/step - loss: 0.6238 - acc: 0.6763 - val_loss: 0.4855 - val_acc: 0.8345
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4350 - acc: 0.8499 - val_loss: 0.4204 - val_acc: 0.8525
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3887 - acc: 0.8571 - val_loss: 0.3954 - val_acc: 0.8561
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3608 - acc: 0.8599 - val_loss: 0.3770 - val_acc: 0.8633
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3395 - acc: 0.8691 - val_loss: 0.3656 - val_acc: 0.8681
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3232 - acc: 0.8731 - val_loss: 0.3535 - val_acc: 0.8753
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3118 - acc: 0.8792 - val_loss: 0.3467 - val_acc: 0.8753
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3008 - acc: 0.8824 - val_loss: 0.3409 - val_acc: 0.8765
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2915 - acc: 0.8864 - val_loss: 0.3361 - val_acc: 0.8801
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2823 - acc: 0.8908 - val_loss: 0.3325 - val_acc: 0.8789
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2745 - acc: 0.8916 - val_loss: 0.3290 - val_acc: 0.8789
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2658 - acc: 0.8996 - val_loss: 0.3278 - val_acc: 0.8813
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2581 - acc: 0.8988 - val_loss: 0.3261 - val_acc: 0.8777
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2502 - acc: 0.9044 - val_loss: 0.3217 - val_acc: 0.8765
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2413 - acc: 0.9080 - val_loss: 0.3183 - val_acc: 0.8837
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2323 - acc: 0.9124 - val_loss: 0.3165 - val_acc: 0.8789
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2244 - acc: 0.9172 - val_loss: 0.3160 - val_acc: 0.8813
# Epoch 18/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2165 - acc: 0.9216 - val_loss: 0.3175 - val_acc: 0.8825
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2099 - acc: 0.9256 - val_loss: 0.3176 - val_acc: 0.8837
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2025 - acc: 0.9264 - val_loss: 0.3164 - val_acc: 0.8897
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1976 - acc: 0.9304 - val_loss: 0.3200 - val_acc: 0.8873
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1924 - acc: 0.9320 - val_loss: 0.3196 - val_acc: 0.8909
# Epoch 22: early stopping

# %%
train_loss_es = history_es.history['loss']
test_loss_es = history_es.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='violet')
plt.plot(test_loss, label='Testing loss', color='lavender')
plt.plot(train_loss_es, label='ES Training loss', color='navy')
plt.plot(test_loss_es, label='ES Testing loss', color='skyblue')
plt.legend();

# %%
history_es.history['acc'][-1], history_es.history['val_acc'][-1]
# Out:
# (0.9319728016853333, 0.8908872604370117)

# %% [markdown]
# ## Keras Resources
# - [Keras EarlyStopping Documentation](https://keras.io/callbacks/#earlystopping)
# - [Keras EarlyStopping Example](http://parneetk.github.io/blog/neural-networks-in-keras/)
#
# ## Tensorflow Resources
# - [Tensorflow.Keras.callbacks.EarlyStopping Documentation](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping)

# %% [markdown]
# # Optimization
# ---
# Now we're going to talk about ways to speed up the process of optimization. Surprisingly, local optima are not often problems with neural networks; there's a much larger issue with "plateaus," or areas where the derivative is approximately 0. This makes learning much slower.
#
# ## Quick Fixes:
# 1. **Feature Scaling:** As we've discussed before, feature scaling can speed up the process of gradient descent. Because gradient descent works "geometrically," the scales of our $w$ values have a large impact on how quickly our parameters converge to the true value. Since we're working with many parameters (often 1,000 or more), scaling our features will speed up optimization.
#
# 2. **Mini-batch Gradient Descent:** In `sklearn`, we use `.fit()` to estimate the parameters in our model. We do the same in neural networks, but if we're working with a very large data set (as is common in neural networks), passing data through our network will cause learning to be slow. By specifying a `batch_size` within the `.fit()` method, we can expedite our learning.
#     - `batch_size`: Integer or `None`. Number of samples per gradient update. If unspecified, it will default to 32.
#
# **Note:** Mini batches will usually be a power of 2 (32, 64, 128, 256, 512) due to the fact that computers operate in base 2.
#
# - [Overview of the three types of gradient descent: batch, stochastic, mini-batch](https://machinelearningmastery.com/gentle-introduction-mini-batch-gradient-descent-configure-batch-size/)

# %% [markdown]
# <a id='momentum'></a>
# ## Gradient Descent with Momentum
#
# One problem we notice with mini-batch gradient descent compared to batch gradient descent is that it tends to oscillate more, due to the fact that at each iteration it is being fed less training data than batch gradient descent.
#
# ![](../assets/grad-descent.png)
# ![](../assets/mini-grad-descent.png)
#
# [*source*](http://pengcheng.tech/2017/09/28/gradient-descent-momentum-and-adam/)
#
# Ideally, we'd like to take advantage of the speed and memory efficiency of mini-batch gradient descent, without the oscillations. We can use the idea of **momentum** to help us out here. (Momentum is based on [exponentially weighted moving averages](https://www.compose.com/articles/metrics-maven-calculating-an-exponentially-weighted-moving-average-in-postgresql/), which causes our oscillations to largely cancel each other out.)
#
# Typically, when updating our parameters, we'll follow this formula:
#
# $$W = W -\alpha\frac{\partial \text{loss}}{\partial W}$$
# $$b = b - \alpha\frac{\partial \text{loss}}{\partial b}$$
#
# We're going to modify this formula to this form:
#
# $$W = W -\alpha V_{\partial W}$$
# $$b = b - \alpha V_{\partial b}$$
#
# Where
# $$V_{\partial W} = \beta V_{\partial W - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial W}$$
# and
# $$V_{\partial b} = \beta V_{\partial b - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial b}$$
#
# When implementing gradient descent with momentum, you'll have two hyperparameters, $\alpha$ and $\beta$. From a practical point of view, $\beta$ is typically $0.9$, but you can test out other values if you'd like.
#
# ### ADAM Optimization
#
# The optimization algorithm you'll likely use when implementing your feed-forward neural network is called ADAM (Adaptive Moment Estimation). It is a combination of gradient descent with momentum and another optimization method called RMSProp (Root Mean Square Propagation). For the sake of this lesson, we won't cover how ADAM works, but with gradient descent with momentum as building block, the ADAM optimization is not too far off, as it largely relies on the concept of momentum.

# %% [markdown]
# ### Data Augmentation
#
# One method of minimizing the risk of overfitting is to gather more data. While this is usually very costly, we may sometimes be able to take our existing data to generate substantially more data.
# - Images: Reflect, crop, random rotations or distortions, adjust lighting.
#     - [The Effectiveness of Data Augmentation in Image Classification using Deep Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
# - Non-Images: [SMOTE](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/) (Synthetic Minority Over-Sampling Technique)

# %% [markdown]
# <a id='conclusion'></a>
# # Conclusion
#
# Today, we learned about three different methods of regularizing our neural networks: Regularization, dropout, and early stopping.
#
# ## Machine Learning Workflow
#
# As promised, managing bias and variance takes a lot of our attention. If our bias or variance are high, it's likely that our model isn't performing as well as it could.
#
# A workflow for how you should address this (in the context of neural networks and beyond) is as follows:
#
# - Do we have high bias? (i.e. are we performing poorly on our training set?)
#     - If so:
#         - let's build a more complex model / bigger network!
#         - let's consider a new architecture for our neural network!
#         - let's train longer!
# - Do we have high variance? (i.e. are we performing poorly on our test/holdout set?)
#     - If so:
#         - let's gather more data!
#             - Usually very difficult, but we should use "data augmentation" if we can!
#         - let's build a simpler model / smaller network!
#         - let's consider a new architecture for our neural network!
#         - let's regularize!
#     - Once we're satisfied, return to the bias question and repeat.
#
# **Note:** Before deep learning, most tools for handling high bias or high variance adversely affected the other. However, depending on the amount of data we have and how complex our network is, it's often the case that we can drastically reduce variance with out affecting bias.
#
# We also learned about Mini-batch Gradient Descent and Gradient Descent with Momentum. You will almost always work with mini batches. And when optimizing, you will generally use a method called Adam Optimization that is built on a combination of Gradient Descent with Momentum and another optimization technique called RMSProp.
#
# We also briefly discussed data augmentation as a method for increasing our sample sie.
#
# <a id='references'></a>
# ## References and Resources:
#
# - [DeepLearning.ai](https://www.deeplearning.ai/), Andrew Ng's Coursera course on Deep Learning
#   - The videos from this course are on a [YouTube Channel](https://www.youtube.com/channel/UCcIXc5mJsHVYTZR1maL5l9w/featured)
# <br>
# - [Deep Learning Book](http://www.deeplearningbook.org/), textbook written by Ian Goodfellow, creator of Generative Adversarial Networks (GANs)
